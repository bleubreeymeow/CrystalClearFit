# %% [markdown]
# # Pr-YBCO version Fit modes C4

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from PrNiO2_C4_alris_functions2 import shift_atoms, transform_list_hkl_p63_p65, get_structure_factors , atom_position_list
from itertools import chain
from matplotlib.markers import MarkerStyle
from tqdm import tqdm
from time import time

# %config InlineBackend.figure_format = 'svg' # make figures appears in .svg style

num_threads = 2  

# Configure TensorFlow to use multiple threads
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.threading.set_inter_op_parallelism_threads(num_threads)

print(f"Using {num_threads} threads for intra-op and inter-op parallelism.")

num_of_params = 14
# Out:
# Using 2 threads for intra-op and inter-op parallelism.

# %% [markdown]
# Define the function containing the fitting parameters
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - `fun_tf()` correspond to the **structure factor calculation function** (one has to convert it to a **TF-compatible** function)
# - <span style="color:red">If conversion to TF-compatible function is not possible, then this approach will probably not work (or becomes much more tedious at least)</span>

# %%
#convert the simulated data to log10 scale (if needed)

def log10(x):
  numerator = tf.math.log(x)
  denominator = tf.math.log(tf.constant(10, dtype=numerator.dtype))
  return numerator / denominator

# %%
def fun_tf(x, pars):
    """
    Fast computation of structure factors with parameter-dependent structure.
        # Get modified structure
    modified_struct = shift_atoms_p65(*pars)
    neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    sf_neg_k = sf_combined[tf.shape(x)[0]:]
    
    intensity = (tf.abs(sf_hkl) + tf.abs(sf_neg_k)) ** 2
    return intensity / tf.reduce_max(intensity)
    """
    # Get modified structure
    atom_shift_list = shift_atoms(*pars)
    print(f"Shape of atom_shift_list: {len(atom_shift_list)}")



    # Flatten atom_shift_list if it contains nested lists
    flat_atom_shift_list = list(chain.from_iterable(
        x if isinstance(x, list) else [x] for x in atom_shift_list
    ))
    modified_struct = atom_position_list(*flat_atom_shift_list)

    #neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = x
    #x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    
    print(f"Shape of sf_combined: {sf_combined.shape}, Shape of x_combined: {x_combined.shape}")
    
    intensity = (tf.abs(sf_hkl)) ** 2
    w = tf.constant(0.00159, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    qnorms = tf.norm(tf.cast(x_combined[:tf.shape(x)[0]], tf.float32), axis=1)
    # qnorms = tf.reshape(qnorms, (-1, 1))  # Reshape to match the shape of intensity
    intensity = intensity * tf.exp(-w * qnorms ** 2)  # Apply Debye-Waller factor
    #intensity = log10(intensity + 1)  # Convert to log10 scale
    return intensity / tf.reduce_max(intensity)

# %%
experimental_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/combined.csv')
"""
# reduce data to l in [0.5, 1.5, 2.5, 3.5, 4.5 ]
experimental_data = experimental_data[
    (experimental_data["l"] == 0.5) |
    (experimental_data["l"] == 1.5) |
    (experimental_data["l"] == 2.5) |
    (experimental_data["l"] == 3.5) |
    (experimental_data["l"] == 4.5)
]
"""

hkl_list = experimental_data[["h", "k", "l"]].values.tolist()
hkl_list = tf.convert_to_tensor(hkl_list, dtype=tf.float32)
print(experimental_data.shape)
# Out:
# (910, 17)

# %% [markdown]
# Sample the "training data" (features and labels)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The features are the (h,k,l) coordinates (e.g. a vector of size `n_features` x 3, i.e. `n_dim = 3`)
# - Maybe one has to normalize the features (i.e. not using integers but floats between -1 (0) and 1)? Before passing them to the structure calculation function, they should be again rescaled to integers
# - The labels would be the experimental intensities (again, maybe have to be normalized to the range between 0 and 1)

# %%
n_features = experimental_data.shape[0]
n_dim = 3

features = hkl_list
labels = experimental_data["intensity_exp"].tolist()
#labels = tf.convert_to_tensor(labels, dtype=tf.float32)

vol_err = experimental_data["intensity_exp_err"].tolist()
labels_err = []
for label, err in zip(labels, vol_err):
    
    labels_err.append(np.log10((label + 1))**1.3)  # Inverse error

labels = labels / np.max(labels)  # Normalize labels

labels_err = tf.convert_to_tensor(labels_err, dtype=tf.float32)
labels = tf.convert_to_tensor(labels, dtype=tf.float32)

labels = tf.expand_dims(labels, axis=-1)  # Ensure labels are 2D
labels_err = tf.expand_dims(labels_err, axis=-1)  # Ensure labels_err are 2D

print("Max label err:", np.max(labels_err))
print("min label err:", np.min(labels_err))
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print('error shape:', labels_err.shape)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))
# Out:
# Max label err: 0.20998715
# min label err: 0.0
# Features shape: (910, 3)
# Labels shape: (910, 1)
# error shape: (910, 1)
# Max label: 1.0
# min label : 0.0

# %% [markdown]
# Define a simple model
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The six parameters (a,b,c,d,e,f) correspond to the fractional atomic shifts in the modes w.r.t. unit cell lengths
# - Instead of `sigmoid`, `tanh` should be applied to the parameters before passing them to the structure factor calculation function (ensures smoother gradient landscape)
# - The `tanh` function can furthermore be limited to a specific range (e.g. if atomic distortions should not exceed +- 0.1)

# %%
class FunAsLayer(tf.keras.layers.Layer):
    def __init__(self, max_mode_amps,**kwargs):
        super().__init__(**kwargs)
        self.max_mode_amps = max_mode_amps

    def build(self, input_shape):
        self.param = self.add_weight(name='param', shape=(num_of_params,), initializer=tf.keras.initializers.he_uniform(), trainable=True)
        super().build(input_shape)

    def call(self, inputs):
        # Apply tanh to ensure parameters stay within the [-1, 1] range then multiply by max_mode_amps so each parameter is scaled corresponding to the element in max_mode_amps
        pretransform = tf.tanh(self.param)
        transformed_params = pretransform * self.max_mode_amps  # Scale parameters

        output = fun_tf(inputs, tf.unstack(transformed_params))
        return tf.reshape(output , [-1])  # Ensure output is 1D

# %% [markdown]
# Create optimizer and define loss function
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The learning rate must be determined by experimentation (same holds for the batch size and the number of epochs below)
# - As a loss function, one can try either MSE or R-score (MSE seems to be the more "natural choice" in this case)

# %%
"""
# R-Score based on intensity
class RFactorLoss(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        return tf.reduce_sum(tf.abs(y_true - y_pred)) / tf.reduce_sum(y_true)
"""
    
# mean squared error
class PerSampleMSE(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__(reduction=tf.keras.losses.Reduction.NONE)

    def call(self, y_true, y_pred):
        squared_error = tf.square(y_true - y_pred)
        per_sample_mse = tf.reduce_mean(squared_error, axis=-1)
        return per_sample_mse  # shape (batch_size,)

class MSE_weighted(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        # Assume y_true = [labels, errors]
        print('ytrue shape:', y_true.shape)
        print('y true' , y_true)
        labels = y_true[:, 0]
        weights = y_true[:, 1]

        mse = tf.square(labels - y_pred)
        return tf.reduce_sum(mse * weights) / tf.reduce_sum(weights)


# Define the custom metric function
def r_factor_metric(y_true, y_pred):
    labels = y_true
    return tf.reduce_sum(tf.abs(labels - y_pred)) / tf.reduce_sum(labels)

# %% [markdown]
# Train the model for n iterations (to try different initial weights)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The number of iterations defines the "starting position" $w_0$ of the gradient descent algorithm
# - Because there are probably many local minima, changing $w_0$ allows the algorithm to find different minima and increases the chances of finding the global minima

# %%
#squeeze labels and labels_err to ensure they are 1D tensors
#labels = tf.squeeze(labels)
#labels_err = tf.squeeze(labels_err)

print("labels shape:", labels.shape)
print("labels_err shape:", labels_err.shape)


lr = [9e-4]
best_pars_overall = None
best_rf_overall = np.inf
best_loss_overall = []
for learning_rate in lr:
    time_start = time()
    print(f"Learning rate: {learning_rate}")
    optim = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    max_mode_amps = tf.constant([2.0,2.0,2.83,2.83,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,2.0,2.0], dtype=tf.float32) 
    print("max_mode_amps shape:", max_mode_amps.shape)

    n_epochs = 1000
    histories = []
    n_iter = 10

    min_loss = np.inf
    best_pars = None

    # List to store the loss values for each epoch
    all_losses = []


    for i in range(n_iter):
        # Create the model
        inputs = tf.keras.Input(shape=(n_dim,))
        outputs = FunAsLayer(max_mode_amps)(inputs)
        model = tf.keras.Model(inputs, outputs)

        # Compile the model with the custom loss function and metric
        model.compile(
            optimizer=optim,
            loss='mse', # MSE_weighted() if using errors
            metrics=[r_factor_metric]

        )
        
        history = model.fit(
        x=features,
        y=labels,  # replace with combined_labels if using errors
        batch_size = features.shape[0], # Use a smaller batch size features.shape[0]
        epochs=n_epochs,
        verbose='auto',
        shuffle=True, # not sure whether this matters
        # callbacks=[cb]
        sample_weight=labels_err  # Use sample weights if you have errors
        )

        histories.append(history)
        all_losses.append(history.history['loss'])
        # Check final loss
        final_loss = history.history['loss'][-1]
        print(model.layers[-1].get_weights()[0].shape)
        curren_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
        print(f"Final loss: {final_loss:.3e}")
        '''
        print(f"Best parameters for iteration {i+1}:")
        for j, par in enumerate(curren_model_pars):
            print(f"Parameter {j+1}: {par.numpy():.4f}")
        '''

        if final_loss < min_loss:
            # Update best model parameters
            best_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
            min_loss = final_loss
            rf = r_factor_metric(labels, fun_tf(features, best_model_pars))
            print(f"Iteration {i+1} - New best loss: {min_loss:.3e} (R-factor: {rf:.3e})")

    if min_loss < best_rf_overall:
        best_rf_overall = min_loss
        best_pars_overall = best_model_pars
        best_loss_overall = all_losses
    print(f"time elapsed: {time() - time_start:.2f} seconds")
    print(f"With {n_epochs*n_iter /(time() - time_start)} iterations per second")
    # Plotting the loss values
    plt.figure(figsize=(10, 6))

    # Plot the loss values for each iteration
    for i, loss_values in enumerate(all_losses):
        plt.plot(loss_values, label=f'Iteration {i+1}')

    plt.title(f'Loss vs Epochs with Learning Rate {learning_rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    # plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# labels shape: (910, 1)
# labels_err shape: (910, 1)
# Learning rate: 0.0009
# max_mode_amps shape: (14,)
# Shape of atom_shift_list: 14
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/1000
# Shape of atom_shift_list: 14
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 14
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 3s 3s/step - loss: 7.0947e-04 - r_factor_metric: 1.0640
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0900e-04 - r_factor_metric: 1.0637
# Epoch 3/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0854e-04 - r_factor_metric: 1.0634
# Epoch 4/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0809e-04 - r_factor_metric: 1.0631
# Epoch 5/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0765e-04 - r_factor_metric: 1.0627
# Epoch 6/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0722e-04 - r_factor_metric: 1.0625
# Epoch 7/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0681e-04 - r_factor_metric: 1.0622
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0640e-04 - r_factor_metric: 1.0619
# Epoch 9/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0600e-04 - r_factor_metric: 1.0617
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0562e-04 - r_factor_metric: 1.0615
# Epoch 11/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0525e-04 - r_factor_metric: 1.0613
# Epoch 12/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.0489e-04 - r_factor_metric: 1.0611
# Epoch 13/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0454e-04 - r_factor_metric: 1.0609
# Epoch 14/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0420e-04 - r_factor_metric: 1.0608
# Epoch 15/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0387e-04 - r_factor_metric: 1.0607
# Epoch 16/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0355e-04 - r_factor_metric: 1.0606
# Epoch 17/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0325e-04 - r_factor_metric: 1.0605
# Epoch 18/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0295e-04 - r_factor_metric: 1.0604
# Epoch 19/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0266e-04 - r_factor_metric: 1.0603
# Epoch 20/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0238e-04 - r_factor_metric: 1.0602
# Epoch 21/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0211e-04 - r_factor_metric: 1.0601
# Epoch 22/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0185e-04 - r_factor_metric: 1.0600
# Epoch 23/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0160e-04 - r_factor_metric: 1.0600
# Epoch 24/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0136e-04 - r_factor_metric: 1.0599
# Epoch 25/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0112e-04 - r_factor_metric: 1.0598
# Epoch 26/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0090e-04 - r_factor_metric: 1.0598
# Epoch 27/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0068e-04 - r_factor_metric: 1.0597
# Epoch 28/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0046e-04 - r_factor_metric: 1.0596
# Epoch 29/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.0026e-04 - r_factor_metric: 1.0596
# Epoch 30/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0006e-04 - r_factor_metric: 1.0596
# Epoch 31/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9987e-04 - r_factor_metric: 1.0597
# Epoch 32/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9968e-04 - r_factor_metric: 1.0597
# Epoch 33/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9950e-04 - r_factor_metric: 1.0597
# Epoch 34/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9932e-04 - r_factor_metric: 1.0597
# Epoch 35/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9915e-04 - r_factor_metric: 1.0597
# Epoch 36/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9898e-04 - r_factor_metric: 1.0597
# Epoch 37/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9882e-04 - r_factor_metric: 1.0597
# Epoch 38/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9866e-04 - r_factor_metric: 1.0597
# Epoch 39/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9851e-04 - r_factor_metric: 1.0597
# Epoch 40/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9836e-04 - r_factor_metric: 1.0597
# Epoch 41/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9822e-04 - r_factor_metric: 1.0597
# Epoch 42/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9807e-04 - r_factor_metric: 1.0596
# Epoch 43/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9793e-04 - r_factor_metric: 1.0596
# Epoch 44/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9780e-04 - r_factor_metric: 1.0596
# Epoch 45/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9766e-04 - r_factor_metric: 1.0596
# Epoch 46/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9753e-04 - r_factor_metric: 1.0596
# Epoch 47/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9740e-04 - r_factor_metric: 1.0596
# Epoch 48/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9728e-04 - r_factor_metric: 1.0596
# Epoch 49/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9715e-04 - r_factor_metric: 1.0595
# Epoch 50/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9703e-04 - r_factor_metric: 1.0595
# Epoch 51/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9691e-04 - r_factor_metric: 1.0595
# Epoch 52/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9679e-04 - r_factor_metric: 1.0595
# Epoch 53/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9668e-04 - r_factor_metric: 1.0594
# Epoch 54/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9656e-04 - r_factor_metric: 1.0594
# Epoch 55/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9645e-04 - r_factor_metric: 1.0594
# Epoch 56/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9633e-04 - r_factor_metric: 1.0594
# Epoch 57/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9622e-04 - r_factor_metric: 1.0593
# Epoch 58/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9611e-04 - r_factor_metric: 1.0593
# Epoch 59/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9600e-04 - r_factor_metric: 1.0592
# Epoch 60/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9590e-04 - r_factor_metric: 1.0592
# Epoch 61/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9579e-04 - r_factor_metric: 1.0592
# Epoch 62/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9568e-04 - r_factor_metric: 1.0591
# Epoch 63/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9558e-04 - r_factor_metric: 1.0591
# Epoch 64/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9547e-04 - r_factor_metric: 1.0590
# Epoch 65/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9537e-04 - r_factor_metric: 1.0590
# Epoch 66/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9527e-04 - r_factor_metric: 1.0590
# Epoch 67/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9517e-04 - r_factor_metric: 1.0589
# Epoch 68/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9507e-04 - r_factor_metric: 1.0589
# Epoch 69/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9497e-04 - r_factor_metric: 1.0588
# Epoch 70/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9487e-04 - r_factor_metric: 1.0588
# Epoch 71/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9477e-04 - r_factor_metric: 1.0588
# Epoch 72/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9467e-04 - r_factor_metric: 1.0587
# Epoch 73/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9457e-04 - r_factor_metric: 1.0587
# Epoch 74/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9447e-04 - r_factor_metric: 1.0586
# Epoch 75/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9437e-04 - r_factor_metric: 1.0586
# Epoch 76/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9428e-04 - r_factor_metric: 1.0585
# Epoch 77/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9418e-04 - r_factor_metric: 1.0585
# Epoch 78/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 6.9409e-04 - r_factor_metric: 1.0584
# Epoch 79/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9399e-04 - r_factor_metric: 1.0584
# Epoch 80/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9390e-04 - r_factor_metric: 1.0583
# Epoch 81/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9380e-04 - r_factor_metric: 1.0583
# Epoch 82/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9371e-04 - r_factor_metric: 1.0582
# Epoch 83/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9362e-04 - r_factor_metric: 1.0582
# Epoch 84/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9352e-04 - r_factor_metric: 1.0581
# Epoch 85/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9343e-04 - r_factor_metric: 1.0581
# Epoch 86/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9334e-04 - r_factor_metric: 1.0580
# Epoch 87/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9325e-04 - r_factor_metric: 1.0580
# Epoch 88/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 6.9316e-04 - r_factor_metric: 1.0579
# Epoch 89/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9307e-04 - r_factor_metric: 1.0578
# Epoch 90/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9298e-04 - r_factor_metric: 1.0578
# Epoch 91/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9289e-04 - r_factor_metric: 1.0577
# Epoch 92/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9280e-04 - r_factor_metric: 1.0577
# Epoch 93/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9271e-04 - r_factor_metric: 1.0576
# Epoch 94/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9262e-04 - r_factor_metric: 1.0576
# Epoch 95/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9253e-04 - r_factor_metric: 1.0575
# Epoch 96/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9245e-04 - r_factor_metric: 1.0574
# Epoch 97/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9236e-04 - r_factor_metric: 1.0574
# Epoch 98/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9227e-04 - r_factor_metric: 1.0573
# Epoch 99/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9219e-04 - r_factor_metric: 1.0572
# Epoch 100/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9210e-04 - r_factor_metric: 1.0572
# Epoch 101/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9202e-04 - r_factor_metric: 1.0571
# Epoch 102/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9193e-04 - r_factor_metric: 1.0571
# Epoch 103/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9185e-04 - r_factor_metric: 1.0570
# Epoch 104/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9176e-04 - r_factor_metric: 1.0569
# Epoch 105/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9168e-04 - r_factor_metric: 1.0569
# Epoch 106/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9160e-04 - r_factor_metric: 1.0568
# Epoch 107/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9151e-04 - r_factor_metric: 1.0567
# Epoch 108/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9143e-04 - r_factor_metric: 1.0567
# Epoch 109/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9135e-04 - r_factor_metric: 1.0566
# Epoch 110/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9127e-04 - r_factor_metric: 1.0566
# Epoch 111/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9119e-04 - r_factor_metric: 1.0565
# Epoch 112/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9110e-04 - r_factor_metric: 1.0564
# Epoch 113/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9102e-04 - r_factor_metric: 1.0564
# Epoch 114/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9094e-04 - r_factor_metric: 1.0563
# Epoch 115/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9086e-04 - r_factor_metric: 1.0562
# Epoch 116/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9078e-04 - r_factor_metric: 1.0562
# Epoch 117/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9071e-04 - r_factor_metric: 1.0561
# Epoch 118/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9063e-04 - r_factor_metric: 1.0561
# Epoch 119/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9055e-04 - r_factor_metric: 1.0560
# Epoch 120/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9047e-04 - r_factor_metric: 1.0559
# Epoch 121/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9039e-04 - r_factor_metric: 1.0559
# Epoch 122/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9032e-04 - r_factor_metric: 1.0558
# Epoch 123/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9024e-04 - r_factor_metric: 1.0557
# Epoch 124/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9016e-04 - r_factor_metric: 1.0557
# Epoch 125/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9009e-04 - r_factor_metric: 1.0556
# Epoch 126/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 6.9001e-04 - r_factor_metric: 1.0555
# Epoch 127/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8994e-04 - r_factor_metric: 1.0555
# Epoch 128/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8986e-04 - r_factor_metric: 1.0554
# Epoch 129/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8979e-04 - r_factor_metric: 1.0554
# Epoch 130/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8971e-04 - r_factor_metric: 1.0553
# Epoch 131/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8964e-04 - r_factor_metric: 1.0552
# Epoch 132/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8956e-04 - r_factor_metric: 1.0552
# Epoch 133/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8949e-04 - r_factor_metric: 1.0551
# Epoch 134/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8942e-04 - r_factor_metric: 1.0550
# Epoch 135/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8935e-04 - r_factor_metric: 1.0550
# Epoch 136/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8927e-04 - r_factor_metric: 1.0549
# Epoch 137/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8920e-04 - r_factor_metric: 1.0548
# Epoch 138/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8913e-04 - r_factor_metric: 1.0548
# Epoch 139/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8906e-04 - r_factor_metric: 1.0547
# Epoch 140/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8899e-04 - r_factor_metric: 1.0547
# Epoch 141/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8892e-04 - r_factor_metric: 1.0546
# Epoch 142/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8885e-04 - r_factor_metric: 1.0545
# Epoch 143/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8878e-04 - r_factor_metric: 1.0545
# Epoch 144/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8871e-04 - r_factor_metric: 1.0544
# Epoch 145/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8864e-04 - r_factor_metric: 1.0544
# Epoch 146/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8857e-04 - r_factor_metric: 1.0543
# Epoch 147/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8850e-04 - r_factor_metric: 1.0542
# Epoch 148/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8843e-04 - r_factor_metric: 1.0542
# Epoch 149/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8836e-04 - r_factor_metric: 1.0541
# Epoch 150/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8830e-04 - r_factor_metric: 1.0540
# Epoch 151/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8823e-04 - r_factor_metric: 1.0540
# Epoch 152/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8816e-04 - r_factor_metric: 1.0539
# Epoch 153/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8810e-04 - r_factor_metric: 1.0539
# Epoch 154/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8803e-04 - r_factor_metric: 1.0538
# Epoch 155/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8796e-04 - r_factor_metric: 1.0537
# Epoch 156/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8790e-04 - r_factor_metric: 1.0537
# Epoch 157/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8783e-04 - r_factor_metric: 1.0536
# Epoch 158/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8777e-04 - r_factor_metric: 1.0536
# Epoch 159/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8770e-04 - r_factor_metric: 1.0535
# Epoch 160/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8764e-04 - r_factor_metric: 1.0535
# Epoch 161/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8757e-04 - r_factor_metric: 1.0534
# Epoch 162/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8751e-04 - r_factor_metric: 1.0534
# Epoch 163/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8745e-04 - r_factor_metric: 1.0533
# Epoch 164/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8738e-04 - r_factor_metric: 1.0533
# Epoch 165/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8732e-04 - r_factor_metric: 1.0532
# Epoch 166/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8726e-04 - r_factor_metric: 1.0532
# Epoch 167/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8719e-04 - r_factor_metric: 1.0531
# Epoch 168/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8713e-04 - r_factor_metric: 1.0531
# Epoch 169/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8707e-04 - r_factor_metric: 1.0530
# Epoch 170/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8701e-04 - r_factor_metric: 1.0530
# Epoch 171/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8695e-04 - r_factor_metric: 1.0529
# Epoch 172/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8688e-04 - r_factor_metric: 1.0529
# Epoch 173/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 6.8682e-04 - r_factor_metric: 1.0528
# Epoch 174/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 6.8676e-04 - r_factor_metric: 1.0528
# Epoch 175/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8670e-04 - r_factor_metric: 1.0527
# Epoch 176/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 6.8664e-04 - r_factor_metric: 1.0527
# Epoch 177/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8658e-04 - r_factor_metric: 1.0526
# Epoch 178/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8652e-04 - r_factor_metric: 1.0526
# Epoch 179/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8646e-04 - r_factor_metric: 1.0525
# Epoch 180/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8640e-04 - r_factor_metric: 1.0525
# Epoch 181/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8635e-04 - r_factor_metric: 1.0524
# Epoch 182/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8629e-04 - r_factor_metric: 1.0524
# Epoch 183/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8623e-04 - r_factor_metric: 1.0523
# Epoch 184/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8617e-04 - r_factor_metric: 1.0523
# Epoch 185/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8611e-04 - r_factor_metric: 1.0522
# Epoch 186/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8606e-04 - r_factor_metric: 1.0522
# Epoch 187/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8600e-04 - r_factor_metric: 1.0521
# Epoch 188/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8594e-04 - r_factor_metric: 1.0521
# Epoch 189/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8588e-04 - r_factor_metric: 1.0520
# Epoch 190/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8583e-04 - r_factor_metric: 1.0520
# Epoch 191/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8577e-04 - r_factor_metric: 1.0519
# Epoch 192/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8572e-04 - r_factor_metric: 1.0519
# Epoch 193/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8566e-04 - r_factor_metric: 1.0518
# Epoch 194/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8560e-04 - r_factor_metric: 1.0518
# Epoch 195/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8555e-04 - r_factor_metric: 1.0517
# Epoch 196/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8549e-04 - r_factor_metric: 1.0517
# Epoch 197/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8544e-04 - r_factor_metric: 1.0516
# Epoch 198/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8538e-04 - r_factor_metric: 1.0516
# Epoch 199/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8533e-04 - r_factor_metric: 1.0515
# Epoch 200/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8528e-04 - r_factor_metric: 1.0515
# Epoch 201/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8522e-04 - r_factor_metric: 1.0514
# Epoch 202/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8517e-04 - r_factor_metric: 1.0514
# Epoch 203/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8511e-04 - r_factor_metric: 1.0513
# Epoch 204/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8506e-04 - r_factor_metric: 1.0513
# Epoch 205/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8501e-04 - r_factor_metric: 1.0512
# Epoch 206/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8496e-04 - r_factor_metric: 1.0512
# Epoch 207/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8490e-04 - r_factor_metric: 1.0511
# Epoch 208/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8485e-04 - r_factor_metric: 1.0511
# Epoch 209/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8480e-04 - r_factor_metric: 1.0510
# Epoch 210/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8475e-04 - r_factor_metric: 1.0510
# Epoch 211/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8469e-04 - r_factor_metric: 1.0509
# Epoch 212/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8464e-04 - r_factor_metric: 1.0509
# Epoch 213/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8459e-04 - r_factor_metric: 1.0508
# Epoch 214/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8454e-04 - r_factor_metric: 1.0508
# Epoch 215/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8449e-04 - r_factor_metric: 1.0507
# Epoch 216/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8444e-04 - r_factor_metric: 1.0507
# Epoch 217/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8439e-04 - r_factor_metric: 1.0506
# Epoch 218/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8434e-04 - r_factor_metric: 1.0506
# Epoch 219/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8429e-04 - r_factor_metric: 1.0505
# Epoch 220/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8424e-04 - r_factor_metric: 1.0505
# Epoch 221/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8419e-04 - r_factor_metric: 1.0504
# Epoch 222/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8414e-04 - r_factor_metric: 1.0503
# Epoch 223/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8409e-04 - r_factor_metric: 1.0503
# Epoch 224/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8404e-04 - r_factor_metric: 1.0502
# Epoch 225/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8399e-04 - r_factor_metric: 1.0502
# Epoch 226/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8394e-04 - r_factor_metric: 1.0501
# Epoch 227/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8390e-04 - r_factor_metric: 1.0501
# Epoch 228/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8385e-04 - r_factor_metric: 1.0500
# Epoch 229/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8380e-04 - r_factor_metric: 1.0500
# Epoch 230/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8375e-04 - r_factor_metric: 1.0499
# Epoch 231/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8370e-04 - r_factor_metric: 1.0499
# Epoch 232/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8366e-04 - r_factor_metric: 1.0498
# Epoch 233/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8361e-04 - r_factor_metric: 1.0498
# Epoch 234/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8356e-04 - r_factor_metric: 1.0497
# Epoch 235/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8352e-04 - r_factor_metric: 1.0497
# Epoch 236/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8347e-04 - r_factor_metric: 1.0496
# Epoch 237/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8342e-04 - r_factor_metric: 1.0496
# Epoch 238/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8338e-04 - r_factor_metric: 1.0495
# Epoch 239/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8333e-04 - r_factor_metric: 1.0495
# Epoch 240/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8328e-04 - r_factor_metric: 1.0494
# Epoch 241/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8324e-04 - r_factor_metric: 1.0494
# Epoch 242/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8319e-04 - r_factor_metric: 1.0493
# Epoch 243/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8315e-04 - r_factor_metric: 1.0493
# Epoch 244/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8310e-04 - r_factor_metric: 1.0492
# Epoch 245/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 6.8306e-04 - r_factor_metric: 1.0492
# Epoch 246/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8301e-04 - r_factor_metric: 1.0492
# Epoch 247/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.8297e-04 - r_factor_metric: 1.0491
# Epoch 248/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8292e-04 - r_factor_metric: 1.0491
# Epoch 249/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8288e-04 - r_factor_metric: 1.0490
# Epoch 250/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8283e-04 - r_factor_metric: 1.0490
# Epoch 251/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8279e-04 - r_factor_metric: 1.0489
# Epoch 252/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8275e-04 - r_factor_metric: 1.0489
# Epoch 253/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8270e-04 - r_factor_metric: 1.0488
# Epoch 254/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8266e-04 - r_factor_metric: 1.0488
# Epoch 255/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8262e-04 - r_factor_metric: 1.0487
# Epoch 256/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8257e-04 - r_factor_metric: 1.0487
# Epoch 257/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8253e-04 - r_factor_metric: 1.0486
# Epoch 258/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8249e-04 - r_factor_metric: 1.0486
# Epoch 259/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8244e-04 - r_factor_metric: 1.0485
# Epoch 260/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8240e-04 - r_factor_metric: 1.0485
# Epoch 261/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8236e-04 - r_factor_metric: 1.0484
# Epoch 262/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8232e-04 - r_factor_metric: 1.0484
# Epoch 263/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8227e-04 - r_factor_metric: 1.0483
# Epoch 264/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8223e-04 - r_factor_metric: 1.0483
# Epoch 265/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8219e-04 - r_factor_metric: 1.0482
# Epoch 266/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8215e-04 - r_factor_metric: 1.0482
# Epoch 267/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8211e-04 - r_factor_metric: 1.0482
# Epoch 268/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8207e-04 - r_factor_metric: 1.0481
# Epoch 269/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8203e-04 - r_factor_metric: 1.0481
# Epoch 270/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8198e-04 - r_factor_metric: 1.0480
# Epoch 271/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8194e-04 - r_factor_metric: 1.0480
# Epoch 272/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8190e-04 - r_factor_metric: 1.0479
# Epoch 273/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8186e-04 - r_factor_metric: 1.0479
# Epoch 274/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8182e-04 - r_factor_metric: 1.0478
# Epoch 275/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8178e-04 - r_factor_metric: 1.0478
# Epoch 276/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8174e-04 - r_factor_metric: 1.0478
# Epoch 277/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8170e-04 - r_factor_metric: 1.0477
# Epoch 278/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8166e-04 - r_factor_metric: 1.0477
# Epoch 279/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8162e-04 - r_factor_metric: 1.0476
# Epoch 280/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8158e-04 - r_factor_metric: 1.0476
# Epoch 281/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8154e-04 - r_factor_metric: 1.0475
# Epoch 282/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8151e-04 - r_factor_metric: 1.0475
# Epoch 283/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8147e-04 - r_factor_metric: 1.0474
# Epoch 284/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8143e-04 - r_factor_metric: 1.0474
# Epoch 285/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8139e-04 - r_factor_metric: 1.0474
# Epoch 286/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8135e-04 - r_factor_metric: 1.0473
# Epoch 287/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8131e-04 - r_factor_metric: 1.0473
# Epoch 288/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8127e-04 - r_factor_metric: 1.0472
# Epoch 289/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8123e-04 - r_factor_metric: 1.0472
# Epoch 290/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8120e-04 - r_factor_metric: 1.0471
# Epoch 291/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8116e-04 - r_factor_metric: 1.0471
# Epoch 292/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8112e-04 - r_factor_metric: 1.0471
# Epoch 293/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8108e-04 - r_factor_metric: 1.0470
# Epoch 294/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8105e-04 - r_factor_metric: 1.0470
# Epoch 295/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8101e-04 - r_factor_metric: 1.0469
# Epoch 296/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8097e-04 - r_factor_metric: 1.0469
# Epoch 297/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8093e-04 - r_factor_metric: 1.0468
# Epoch 298/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8090e-04 - r_factor_metric: 1.0468
# Epoch 299/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 6.8086e-04 - r_factor_metric: 1.0468
# Epoch 300/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8082e-04 - r_factor_metric: 1.0467
# Epoch 301/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8079e-04 - r_factor_metric: 1.0467
# Epoch 302/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8075e-04 - r_factor_metric: 1.0467
# Epoch 303/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8071e-04 - r_factor_metric: 1.0466
# Epoch 304/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8068e-04 - r_factor_metric: 1.0466
# Epoch 305/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8064e-04 - r_factor_metric: 1.0466
# Epoch 306/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8061e-04 - r_factor_metric: 1.0465
# Epoch 307/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8057e-04 - r_factor_metric: 1.0465
# Epoch 308/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8053e-04 - r_factor_metric: 1.0465
# Epoch 309/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8050e-04 - r_factor_metric: 1.0464
# Epoch 310/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8046e-04 - r_factor_metric: 1.0464
# Epoch 311/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8043e-04 - r_factor_metric: 1.0464
# Epoch 312/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8039e-04 - r_factor_metric: 1.0463
# Epoch 313/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8036e-04 - r_factor_metric: 1.0463
# Epoch 314/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8032e-04 - r_factor_metric: 1.0463
# Epoch 315/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8029e-04 - r_factor_metric: 1.0462
# Epoch 316/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8025e-04 - r_factor_metric: 1.0462
# Epoch 317/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8022e-04 - r_factor_metric: 1.0462
# Epoch 318/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8018e-04 - r_factor_metric: 1.0461
# Epoch 319/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8015e-04 - r_factor_metric: 1.0461
# Epoch 320/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8012e-04 - r_factor_metric: 1.0461
# Epoch 321/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8008e-04 - r_factor_metric: 1.0460
# Epoch 322/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8005e-04 - r_factor_metric: 1.0460
# Epoch 323/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8001e-04 - r_factor_metric: 1.0460
# Epoch 324/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7998e-04 - r_factor_metric: 1.0459
# Epoch 325/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7995e-04 - r_factor_metric: 1.0459
# Epoch 326/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7991e-04 - r_factor_metric: 1.0459
# Epoch 327/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7988e-04 - r_factor_metric: 1.0458
# Epoch 328/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7985e-04 - r_factor_metric: 1.0458
# Epoch 329/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7981e-04 - r_factor_metric: 1.0458
# Epoch 330/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7978e-04 - r_factor_metric: 1.0457
# Epoch 331/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7975e-04 - r_factor_metric: 1.0457
# Epoch 332/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7971e-04 - r_factor_metric: 1.0457
# Epoch 333/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7968e-04 - r_factor_metric: 1.0456
# Epoch 334/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7965e-04 - r_factor_metric: 1.0456
# Epoch 335/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 6.7962e-04 - r_factor_metric: 1.0456
# Epoch 336/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7958e-04 - r_factor_metric: 1.0455
# Epoch 337/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7955e-04 - r_factor_metric: 1.0455
# Epoch 338/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7952e-04 - r_factor_metric: 1.0455
# Epoch 339/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7949e-04 - r_factor_metric: 1.0454
# Epoch 340/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7945e-04 - r_factor_metric: 1.0454
# Epoch 341/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7942e-04 - r_factor_metric: 1.0454
# Epoch 342/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7939e-04 - r_factor_metric: 1.0453
# Epoch 343/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7936e-04 - r_factor_metric: 1.0453
# Epoch 344/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7933e-04 - r_factor_metric: 1.0453
# Epoch 345/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7930e-04 - r_factor_metric: 1.0452
# Epoch 346/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7926e-04 - r_factor_metric: 1.0452
# Epoch 347/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7923e-04 - r_factor_metric: 1.0452
# Epoch 348/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7920e-04 - r_factor_metric: 1.0451
# Epoch 349/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7917e-04 - r_factor_metric: 1.0451
# Epoch 350/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7914e-04 - r_factor_metric: 1.0451
# Epoch 351/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 6.7911e-04 - r_factor_metric: 1.0450
# Epoch 352/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7908e-04 - r_factor_metric: 1.0450
# Epoch 353/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7905e-04 - r_factor_metric: 1.0449
# Epoch 354/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7902e-04 - r_factor_metric: 1.0449
# Epoch 355/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7899e-04 - r_factor_metric: 1.0449
# Epoch 356/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7895e-04 - r_factor_metric: 1.0448
# Epoch 357/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7892e-04 - r_factor_metric: 1.0448
# Epoch 358/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7889e-04 - r_factor_metric: 1.0448
# Epoch 359/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7886e-04 - r_factor_metric: 1.0447
# Epoch 360/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7883e-04 - r_factor_metric: 1.0447
# Epoch 361/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7880e-04 - r_factor_metric: 1.0447
# Epoch 362/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7877e-04 - r_factor_metric: 1.0446
# Epoch 363/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7874e-04 - r_factor_metric: 1.0446
# Epoch 364/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7871e-04 - r_factor_metric: 1.0446
# Epoch 365/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7868e-04 - r_factor_metric: 1.0445
# Epoch 366/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7865e-04 - r_factor_metric: 1.0445
# Epoch 367/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7863e-04 - r_factor_metric: 1.0445
# Epoch 368/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7860e-04 - r_factor_metric: 1.0444
# Epoch 369/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7857e-04 - r_factor_metric: 1.0444
# Epoch 370/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7854e-04 - r_factor_metric: 1.0444
# Epoch 371/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7851e-04 - r_factor_metric: 1.0443
# Epoch 372/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7848e-04 - r_factor_metric: 1.0443
# Epoch 373/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.7845e-04 - r_factor_metric: 1.0443
# Epoch 374/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7842e-04 - r_factor_metric: 1.0442
# Epoch 375/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7839e-04 - r_factor_metric: 1.0442
# Epoch 376/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7836e-04 - r_factor_metric: 1.0442
# Epoch 377/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7833e-04 - r_factor_metric: 1.0441
# Epoch 378/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7831e-04 - r_factor_metric: 1.0441
# Epoch 379/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 6.7828e-04 - r_factor_metric: 1.0441
# Epoch 380/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7825e-04 - r_factor_metric: 1.0440
# Epoch 381/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7822e-04 - r_factor_metric: 1.0440
# Epoch 382/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7819e-04 - r_factor_metric: 1.0440
# Epoch 383/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7816e-04 - r_factor_metric: 1.0439
# Epoch 384/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7814e-04 - r_factor_metric: 1.0439
# Epoch 385/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7811e-04 - r_factor_metric: 1.0439
# Epoch 386/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7808e-04 - r_factor_metric: 1.0438
# Epoch 387/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7805e-04 - r_factor_metric: 1.0438
# Epoch 388/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7803e-04 - r_factor_metric: 1.0438
# Epoch 389/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 6.7800e-04 - r_factor_metric: 1.0437
# Epoch 390/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 6.7797e-04 - r_factor_metric: 1.0437
# Epoch 391/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7794e-04 - r_factor_metric: 1.0437
# Epoch 392/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7791e-04 - r_factor_metric: 1.0436
# Epoch 393/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7789e-04 - r_factor_metric: 1.0436
# Epoch 394/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7786e-04 - r_factor_metric: 1.0436
# Epoch 395/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7783e-04 - r_factor_metric: 1.0435
# Epoch 396/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7781e-04 - r_factor_metric: 1.0435
# Epoch 397/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7778e-04 - r_factor_metric: 1.0435
# Epoch 398/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7775e-04 - r_factor_metric: 1.0434
# Epoch 399/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.7772e-04 - r_factor_metric: 1.0434
# Epoch 400/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7770e-04 - r_factor_metric: 1.0434
# Epoch 401/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7767e-04 - r_factor_metric: 1.0433
# Epoch 402/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7764e-04 - r_factor_metric: 1.0433
# Epoch 403/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7762e-04 - r_factor_metric: 1.0433
# Epoch 404/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7759e-04 - r_factor_metric: 1.0433
# Epoch 405/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7756e-04 - r_factor_metric: 1.0432
# Epoch 406/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7754e-04 - r_factor_metric: 1.0432
# Epoch 407/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7751e-04 - r_factor_metric: 1.0432
# Epoch 408/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7749e-04 - r_factor_metric: 1.0431
# Epoch 409/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7746e-04 - r_factor_metric: 1.0431
# Epoch 410/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7743e-04 - r_factor_metric: 1.0431
# Epoch 411/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7741e-04 - r_factor_metric: 1.0430
# Epoch 412/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7738e-04 - r_factor_metric: 1.0430
# Epoch 413/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7735e-04 - r_factor_metric: 1.0430
# Epoch 414/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7733e-04 - r_factor_metric: 1.0429
# Epoch 415/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7730e-04 - r_factor_metric: 1.0429
# Epoch 416/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7728e-04 - r_factor_metric: 1.0429
# Epoch 417/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7725e-04 - r_factor_metric: 1.0429
# Epoch 418/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7723e-04 - r_factor_metric: 1.0428
# Epoch 419/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7720e-04 - r_factor_metric: 1.0428
# Epoch 420/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7717e-04 - r_factor_metric: 1.0428
# Epoch 421/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7715e-04 - r_factor_metric: 1.0427
# Epoch 422/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7712e-04 - r_factor_metric: 1.0427
# Epoch 423/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7710e-04 - r_factor_metric: 1.0427
# Epoch 424/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7707e-04 - r_factor_metric: 1.0426
# Epoch 425/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7705e-04 - r_factor_metric: 1.0426
# Epoch 426/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7702e-04 - r_factor_metric: 1.0426
# Epoch 427/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7700e-04 - r_factor_metric: 1.0426
# Epoch 428/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7697e-04 - r_factor_metric: 1.0425
# Epoch 429/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7695e-04 - r_factor_metric: 1.0425
# Epoch 430/1000
# ...
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3466e-04 - r_factor_metric: 1.0017
# Epoch 872/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3465e-04 - r_factor_metric: 1.0017
# Epoch 873/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3465e-04 - r_factor_metric: 1.0017
# Epoch 874/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3464e-04 - r_factor_metric: 1.0017
# Epoch 875/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3464e-04 - r_factor_metric: 1.0017
# Epoch 876/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3464e-04 - r_factor_metric: 1.0017
# Epoch 877/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3463e-04 - r_factor_metric: 1.0017
# Epoch 878/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3463e-04 - r_factor_metric: 1.0017
# Epoch 879/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3462e-04 - r_factor_metric: 1.0017
# Epoch 880/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 6.3462e-04 - r_factor_metric: 1.0017
# Epoch 881/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3462e-04 - r_factor_metric: 1.0017
# Epoch 882/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.3461e-04 - r_factor_metric: 1.0017
# Epoch 883/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3461e-04 - r_factor_metric: 1.0017
# Epoch 884/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3460e-04 - r_factor_metric: 1.0017
# Epoch 885/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3460e-04 - r_factor_metric: 1.0017
# Epoch 886/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3459e-04 - r_factor_metric: 1.0017
# Epoch 887/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3459e-04 - r_factor_metric: 1.0017
# Epoch 888/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3459e-04 - r_factor_metric: 1.0017
# Epoch 889/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3458e-04 - r_factor_metric: 1.0017
# Epoch 890/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3458e-04 - r_factor_metric: 1.0017
# Epoch 891/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3457e-04 - r_factor_metric: 1.0017
# Epoch 892/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3457e-04 - r_factor_metric: 1.0017
# Epoch 893/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3457e-04 - r_factor_metric: 1.0017
# Epoch 894/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3456e-04 - r_factor_metric: 1.0017
# Epoch 895/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3456e-04 - r_factor_metric: 1.0017
# Epoch 896/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3455e-04 - r_factor_metric: 1.0017
# Epoch 897/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3455e-04 - r_factor_metric: 1.0017
# Epoch 898/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3455e-04 - r_factor_metric: 1.0017
# Epoch 899/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3454e-04 - r_factor_metric: 1.0017
# Epoch 900/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3454e-04 - r_factor_metric: 1.0017
# Epoch 901/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3453e-04 - r_factor_metric: 1.0017
# Epoch 902/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3453e-04 - r_factor_metric: 1.0017
# Epoch 903/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3453e-04 - r_factor_metric: 1.0017
# Epoch 904/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3452e-04 - r_factor_metric: 1.0017
# Epoch 905/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3452e-04 - r_factor_metric: 1.0017
# Epoch 906/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3451e-04 - r_factor_metric: 1.0017
# Epoch 907/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3451e-04 - r_factor_metric: 1.0017
# Epoch 908/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3451e-04 - r_factor_metric: 1.0017
# Epoch 909/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3450e-04 - r_factor_metric: 1.0017
# Epoch 910/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3450e-04 - r_factor_metric: 1.0017
# Epoch 911/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3450e-04 - r_factor_metric: 1.0016
# Epoch 912/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3449e-04 - r_factor_metric: 1.0016
# Epoch 913/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3449e-04 - r_factor_metric: 1.0016
# Epoch 914/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3448e-04 - r_factor_metric: 1.0016
# Epoch 915/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3448e-04 - r_factor_metric: 1.0016
# Epoch 916/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3448e-04 - r_factor_metric: 1.0016
# Epoch 917/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3447e-04 - r_factor_metric: 1.0016
# Epoch 918/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3447e-04 - r_factor_metric: 1.0016
# Epoch 919/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3446e-04 - r_factor_metric: 1.0016
# Epoch 920/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3446e-04 - r_factor_metric: 1.0016
# Epoch 921/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3446e-04 - r_factor_metric: 1.0016
# Epoch 922/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3445e-04 - r_factor_metric: 1.0016
# Epoch 923/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3445e-04 - r_factor_metric: 1.0016
# Epoch 924/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3444e-04 - r_factor_metric: 1.0016
# Epoch 925/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3444e-04 - r_factor_metric: 1.0016
# Epoch 926/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3444e-04 - r_factor_metric: 1.0016
# Epoch 927/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3443e-04 - r_factor_metric: 1.0016
# Epoch 928/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3443e-04 - r_factor_metric: 1.0016
# Epoch 929/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3443e-04 - r_factor_metric: 1.0016
# Epoch 930/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3442e-04 - r_factor_metric: 1.0016
# Epoch 931/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3442e-04 - r_factor_metric: 1.0016
# Epoch 932/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3441e-04 - r_factor_metric: 1.0016
# Epoch 933/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3441e-04 - r_factor_metric: 1.0016
# Epoch 934/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3441e-04 - r_factor_metric: 1.0016
# Epoch 935/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3440e-04 - r_factor_metric: 1.0016
# Epoch 936/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3440e-04 - r_factor_metric: 1.0016
# Epoch 937/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3440e-04 - r_factor_metric: 1.0016
# Epoch 938/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3439e-04 - r_factor_metric: 1.0016
# Epoch 939/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3439e-04 - r_factor_metric: 1.0016
# Epoch 940/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3438e-04 - r_factor_metric: 1.0016
# Epoch 941/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3438e-04 - r_factor_metric: 1.0016
# Epoch 942/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3438e-04 - r_factor_metric: 1.0016
# Epoch 943/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3437e-04 - r_factor_metric: 1.0016
# Epoch 944/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3437e-04 - r_factor_metric: 1.0016
# Epoch 945/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3437e-04 - r_factor_metric: 1.0016
# Epoch 946/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3436e-04 - r_factor_metric: 1.0016
# Epoch 947/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3436e-04 - r_factor_metric: 1.0016
# Epoch 948/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3435e-04 - r_factor_metric: 1.0016
# Epoch 949/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3435e-04 - r_factor_metric: 1.0016
# Epoch 950/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3435e-04 - r_factor_metric: 1.0016
# Epoch 951/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3434e-04 - r_factor_metric: 1.0016
# Epoch 952/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3434e-04 - r_factor_metric: 1.0016
# Epoch 953/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3434e-04 - r_factor_metric: 1.0016
# Epoch 954/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3433e-04 - r_factor_metric: 1.0016
# Epoch 955/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3433e-04 - r_factor_metric: 1.0016
# Epoch 956/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3432e-04 - r_factor_metric: 1.0016
# Epoch 957/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3432e-04 - r_factor_metric: 1.0016
# Epoch 958/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3432e-04 - r_factor_metric: 1.0016
# Epoch 959/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3431e-04 - r_factor_metric: 1.0016
# Epoch 960/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3431e-04 - r_factor_metric: 1.0016
# Epoch 961/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3431e-04 - r_factor_metric: 1.0016
# Epoch 962/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3430e-04 - r_factor_metric: 1.0016
# Epoch 963/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3430e-04 - r_factor_metric: 1.0016
# Epoch 964/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3430e-04 - r_factor_metric: 1.0016
# Epoch 965/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3429e-04 - r_factor_metric: 1.0016
# Epoch 966/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3429e-04 - r_factor_metric: 1.0016
# Epoch 967/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3428e-04 - r_factor_metric: 1.0016
# Epoch 968/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3428e-04 - r_factor_metric: 1.0016
# Epoch 969/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3428e-04 - r_factor_metric: 1.0016
# Epoch 970/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3427e-04 - r_factor_metric: 1.0016
# Epoch 971/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3427e-04 - r_factor_metric: 1.0016
# Epoch 972/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3427e-04 - r_factor_metric: 1.0016
# Epoch 973/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3426e-04 - r_factor_metric: 1.0016
# Epoch 974/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3426e-04 - r_factor_metric: 1.0016
# Epoch 975/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3426e-04 - r_factor_metric: 1.0016
# Epoch 976/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3425e-04 - r_factor_metric: 1.0016
# Epoch 977/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3425e-04 - r_factor_metric: 1.0016
# Epoch 978/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3425e-04 - r_factor_metric: 1.0016
# Epoch 979/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3424e-04 - r_factor_metric: 1.0016
# Epoch 980/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 6.3424e-04 - r_factor_metric: 1.0015
# Epoch 981/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3423e-04 - r_factor_metric: 1.0015
# Epoch 982/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3423e-04 - r_factor_metric: 1.0015
# Epoch 983/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 6.3423e-04 - r_factor_metric: 1.0015
# Epoch 984/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 6.3422e-04 - r_factor_metric: 1.0015
# Epoch 985/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3422e-04 - r_factor_metric: 1.0015
# Epoch 986/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3422e-04 - r_factor_metric: 1.0015
# Epoch 987/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3421e-04 - r_factor_metric: 1.0015
# Epoch 988/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3421e-04 - r_factor_metric: 1.0015
# Epoch 989/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3421e-04 - r_factor_metric: 1.0015
# Epoch 990/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3420e-04 - r_factor_metric: 1.0015
# Epoch 991/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3420e-04 - r_factor_metric: 1.0015
# Epoch 992/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3420e-04 - r_factor_metric: 1.0015
# Epoch 993/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3419e-04 - r_factor_metric: 1.0015
# Epoch 994/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3419e-04 - r_factor_metric: 1.0015
# Epoch 995/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3419e-04 - r_factor_metric: 1.0015
# Epoch 996/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3418e-04 - r_factor_metric: 1.0015
# Epoch 997/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3418e-04 - r_factor_metric: 1.0015
# Epoch 998/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3418e-04 - r_factor_metric: 1.0015
# Epoch 999/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3417e-04 - r_factor_metric: 1.0015
# Epoch 1000/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3417e-04 - r_factor_metric: 1.0015
# (14,)
# Final loss: 6.342e-04
# Shape of atom_shift_list: 14
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x000001F746E04700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x000001F746E043A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Iteration 2 - New best loss: 6.342e-04 (R-factor: 9.633e+02)
# time elapsed: 28.31 seconds
# With 70.64709964692064 iterations per second

# %%
all_losses = best_loss_overall
best_model_pars = best_pars_overall
min_loss = best_rf_overall

print(f"min loss: {min_loss}")


# Plotting the loss values
plt.figure(figsize=(10, 6))

# Plot the loss values for each iteration
for i, loss_values in enumerate(all_losses):
    plt.plot(loss_values, label=f'Iteration {i+1}')

plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.grid(True)
plt.show()
# Out:
# min loss: 0.0004905876121483743

# %%
mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/PrNiO2_C4_displacivemode_names.txt' , delim_whitespace=True, header=None)

mode_names = mode_names.values.tolist()
mode_names = pd.DataFrame(mode_names)

# Print the best model parameters
print("Best model parameters:") 
for i, par in enumerate(best_model_pars):
    print(f"{mode_names.iloc[i , 1]} : {par.numpy():.8f}")
    
# Print the model summary
print("Number of iterations:", n_iter)
print("Number of features:", n_features)
#modes = get_mode_amplitudes_p63(*best_model_pars)
#print("Modes:")
##for key, val in modes.items():
    #print(f"{key}: {val*1000:.4f}")
# Out:
# Best model parameters:
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Pr1:d:dsp]A2u(a) : -1.72591758
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Pr1:d:dsp]A2u(b) : -0.57288700
# P4/mmm[0,1/2,0]X1+(a;a)[Pr1:d:dsp]Eu(a) : -0.17568931
# P4/mmm[0,1/2,0]X2+(a;a)[Pr1:d:dsp]Eu(a) : -1.24763834
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B3u(a) : -1.13005626
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B3u(b) : 1.12922978
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B2u(a) : 1.91375422
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B2u(b) : -1.91296709
# P4/mmm[1/2,1/2,0]M1+(a)[O1:f:dsp]B2u(a) : 1.21749091
# P4/mmm[1/2,1/2,0]M4+(a)[O1:f:dsp]B3u(a) : -1.93602777
# P4/mmm[0,1/2,0]X1+(a;a)[O1:f:dsp]B2u(a) : 2.86795664
# P4/mmm[0,1/2,0]X2+(a;a)[O1:f:dsp]B3u(a) : -0.00039893
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Ni1:a:dsp]Eu(a) : -1.53223431
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Ni1:a:dsp]Eu(b) : 1.65414798
# Number of iterations: 2
# Number of features: 910
# C:\Users\User\AppData\Local\Temp\ipykernel_25228\2965176560.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/PrNiO2_C4_displacivemode_names.txt' , delim_whitespace=True, header=None)

# %%
def plot_plane_sim_vs_exp(ax, df, l, norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.max(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.max(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_sim'] * 300, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="left"))
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_exp'] * 300, color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="right"))
    
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    ax.set_title(f"l = {l}")
    ax.legend()

# %%
exp_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/combined.csv')
exp_data['intensity_sim'] = fun_tf(features, best_model_pars).numpy()
# Out:
# Shape of atom_shift_list: 14
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)

# %%
# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], exp_data, l, norm_plane=True)

plt.show()

# %%
#save the experiment data with simulated intensities
exp_data.to_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt', index=False)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_parameters_and_modes.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars):
        f.write(f"{mode_names.iloc[i, 0]} : {par.numpy():.8f} \n")

abs_params = tf.abs(best_model_pars)
best_model_pars_compare = best_model_pars.numpy()
best_model_pars_compare = best_model_pars_compare / np.max(best_model_pars_compare)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_parameters_and_modes_normalised.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars_compare):
        f.write(f"{mode_names.iloc[i, 1]} : {par:.8f} \n")

# %%
best_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt')


# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], best_data, l, norm_plane=True)

plt.show()
