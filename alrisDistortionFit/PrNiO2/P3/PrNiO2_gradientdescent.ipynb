# %% [markdown]
# # Pr-YBCO version Fit modes P3

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from PrNiO2_alris_functions2 import shift_atoms, transform_list_hkl_p63_p65, get_structure_factors , atom_position_list
from itertools import chain
from matplotlib.markers import MarkerStyle
from tqdm import tqdm
from time import time

# %config InlineBackend.figure_format = 'svg' # make figures appears in .svg style




num_threads = 2  

# Configure TensorFlow to use multiple threads
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.threading.set_inter_op_parallelism_threads(num_threads)

print(f"Using {num_threads} threads for intra-op and inter-op parallelism.")
# Out:
# Using 2 threads for intra-op and inter-op parallelism.

# %% [markdown]
# Define the function containing the fitting parameters
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - `fun_tf()` correspond to the **structure factor calculation function** (one has to convert it to a **TF-compatible** function)
# - <span style="color:red">If conversion to TF-compatible function is not possible, then this approach will probably not work (or becomes much more tedious at least)</span>

# %%
#convert the simulated data to log10 scale

def log10(x):
  numerator = tf.math.log(x)
  denominator = tf.math.log(tf.constant(10, dtype=numerator.dtype))
  return numerator / denominator

# %%
def fun_tf(x, pars):
    """
    Fast computation of structure factors with parameter-dependent structure.
        # Get modified structure
    modified_struct = shift_atoms_p65(*pars)
    neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    sf_neg_k = sf_combined[tf.shape(x)[0]:]
    
    intensity = (tf.abs(sf_hkl) + tf.abs(sf_neg_k)) ** 2
    return intensity / tf.reduce_max(intensity)
    """
    # Get modified structure
    atom_shift_list = shift_atoms(*pars)
    print(f"Shape of atom_shift_list: {len(atom_shift_list)}")



    # Flatten atom_shift_list if it contains nested lists
    flat_atom_shift_list = list(chain.from_iterable(
        x if isinstance(x, list) else [x] for x in atom_shift_list
    ))
    modified_struct = atom_position_list(*flat_atom_shift_list)

    #neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = x
    #x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    
    print(f"Shape of sf_combined: {sf_combined.shape}, Shape of x_combined: {x_combined.shape}")
    
    intensity = (tf.abs(sf_hkl)) ** 2
    w = tf.constant(0.00159, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    qnorms = tf.norm(tf.cast(x_combined[:tf.shape(x)[0]], tf.float32), axis=1)
    # qnorms = tf.reshape(qnorms, (-1, 1))  # Reshape to match the shape of intensity
    intensity = intensity * tf.exp(-w * qnorms ** 2)  # Apply Debye-Waller factor
    #intensity = log10(intensity + 1)  # Convert to log10 scale
    return intensity / tf.reduce_max(intensity)

# %%
experimental_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/raw_data/combined.csv')
"""
# reduce data to l in [0.5, 1.5, 2.5, 3.5, 4.5 ]
experimental_data = experimental_data[
    (experimental_data["l"] == 0.5) |
    (experimental_data["l"] == 1.5) |
    (experimental_data["l"] == 2.5) |
    (experimental_data["l"] == 3.5) |
    (experimental_data["l"] == 4.5)
]
"""

hkl_list = experimental_data[["h", "k", "l"]].values.tolist()
hkl_list = tf.convert_to_tensor(hkl_list, dtype=tf.float32)
print(experimental_data.shape)
print(hkl_list[0:5])
# Out:
# (910, 17)
# tf.Tensor(
# [[-0.5 -0.5  0. ]
#  [ 0.5 -0.5  0. ]
#  [-1.5 -0.5  0. ]
#  [ 1.5 -0.5  0. ]
#  [-2.5 -0.5  0. ]], shape=(5, 3), dtype=float32)

# %% [markdown]
# Sample the "training data" (features and labels)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The features are the (h,k,l) coordinates (e.g. a vector of size `n_features` x 3, i.e. `n_dim = 3`)
# - Maybe one has to normalize the features (i.e. not using integers but floats between -1 (0) and 1)? Before passing them to the structure calculation function, they should be again rescaled to integers
# - The labels would be the experimental intensities (again, maybe have to be normalized to the range between 0 and 1)

# %%
n_features = experimental_data.shape[0]
n_dim = 3

features = hkl_list
labels = experimental_data["intensity_exp"].tolist()
#labels = tf.convert_to_tensor(labels, dtype=tf.float32)

vol_err = experimental_data["intensity_exp_err"].tolist()
labels_err = []
for label, err in zip(labels, vol_err):
    
    labels_err.append(np.log10((label + 1))**1.3)  # Inverse error

labels = labels / np.max(labels)  # Normalize labels

labels_err = tf.convert_to_tensor(labels_err, dtype=tf.float32)
labels = tf.convert_to_tensor(labels, dtype=tf.float32)

labels = tf.expand_dims(labels, axis=-1)  # Ensure labels are 2D
labels_err = tf.expand_dims(labels_err, axis=-1)  # Ensure labels_err are 2D

print("Max label err:", np.max(labels_err))
print("min label err:", np.min(labels_err))
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print('error shape:', labels_err.shape)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))
# Out:
# Max label err: 0.20998715
# min label err: 0.0
# Features shape: (910, 3)
# Labels shape: (910, 1)
# error shape: (910, 1)
# Max label: 1.0
# min label : 0.0

# %% [markdown]
# Define a simple model
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The six parameters (a,b,c,d,e,f) correspond to the fractional atomic shifts in the modes w.r.t. unit cell lengths
# - Instead of `sigmoid`, `tanh` should be applied to the parameters before passing them to the structure factor calculation function (ensures smoother gradient landscape)
# - The `tanh` function can furthermore be limited to a specific range (e.g. if atomic distortions should not exceed +- 0.1)

# %%
class FunAsLayer(tf.keras.layers.Layer):
    def __init__(self, max_mode_amps,**kwargs):
        super().__init__(**kwargs)
        self.max_mode_amps = max_mode_amps

    def build(self, input_shape):
        self.param = self.add_weight(name='param', shape=(7,), initializer=tf.keras.initializers.he_uniform(), trainable=True)
        super().build(input_shape)

    def call(self, inputs):
        # Apply tanh to ensure parameters stay within the [-1, 1] range then multiply by max_mode_amps so each parameter is scaled corresponding to the element in max_mode_amps
        pretransform = tf.tanh(self.param)
        transformed_params = pretransform * self.max_mode_amps  # Scale parameters

        output = fun_tf(inputs, tf.unstack(transformed_params))
        return tf.reshape(output , [-1])  # Ensure output is 1D

# %% [markdown]
# Create optimizer and define loss function
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The learning rate must be determined by experimentation (same holds for the batch size and the number of epochs below)
# - As a loss function, one can try either MSE or R-score (MSE seems to be the more "natural choice" in this case)

# %%
"""
# R-Score based on intensity
class RFactorLoss(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        return tf.reduce_sum(tf.abs(y_true - y_pred)) / tf.reduce_sum(y_true)
"""
    
# mean squared error
class PerSampleMSE(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__(reduction=tf.keras.losses.Reduction.NONE)

    def call(self, y_true, y_pred):
        squared_error = tf.square(y_true - y_pred)
        per_sample_mse = tf.reduce_mean(squared_error, axis=-1)
        return per_sample_mse  # shape (batch_size,)

class MSE_weighted(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        # Assume y_true = [labels, errors]
        print('ytrue shape:', y_true.shape)
        print('y true' , y_true)
        labels = y_true[:, 0]
        weights = y_true[:, 1]

        mse = tf.square(labels - y_pred)
        return tf.reduce_sum(mse * weights) / tf.reduce_sum(weights)


# Define the custom metric function
def r_factor_metric(y_true, y_pred):
    labels = y_true
    return tf.reduce_sum(tf.abs(labels - y_pred)) / tf.reduce_sum(labels)

# %% [markdown]
# Train the model for n iterations (to try different initial weights)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The number of iterations defines the "starting position" $w_0$ of the gradient descent algorithm
# - Because there are probably many local minima, changing $w_0$ allows the algorithm to find different minima and increases the chances of finding the global minima

# %%
#squeeze labels and labels_err to ensure they are 1D tensors
#labels = tf.squeeze(labels)
#labels_err = tf.squeeze(labels_err)

print("labels shape:", labels.shape)
print("labels_err shape:", labels_err.shape)


lr = [9e-4]
best_pars_overall = None
best_rf_overall = np.inf
best_loss_overall = []
for learning_rate in lr:
    time_start = time()
    print(f"Learning rate: {learning_rate}")
    optim = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    max_mode_amps = tf.constant([2.83 , 2.83 , 2.83 , 2.83 , 4.00 , 4.00 , 2.00], dtype=tf.float32) 
    print("max_mode_amps shape:", max_mode_amps.shape)

    n_epochs = 1000
    histories = []
    n_iter = 2

    min_loss = np.inf
    best_pars = None

    # List to store the loss values for each epoch
    all_losses = []


    for i in range(n_iter):
        # Create the model
        inputs = tf.keras.Input(shape=(n_dim,))
        outputs = FunAsLayer(max_mode_amps)(inputs)
        model = tf.keras.Model(inputs, outputs)

        # Compile the model with the custom loss function and metric
        model.compile(
            optimizer=optim,
            loss='mse', # MSE_weighted() if using errors
            metrics=[r_factor_metric]

        )
        
        history = model.fit(
        x=features,
        y=labels,  # replace with combined_labels if using errors
        batch_size = features.shape[0], # Use a smaller batch size features.shape[0]
        epochs=n_epochs,
        verbose='auto',
        shuffle=True, # not sure whether this matters
        # callbacks=[cb]
        sample_weight=labels_err  # Use sample weights if you have errors
        )

        histories.append(history)
        all_losses.append(history.history['loss'])
        # Check final loss
        final_loss = history.history['loss'][-1]
        print(model.layers[-1].get_weights()[0].shape)
        curren_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
        print(f"Final loss: {final_loss:.3e}")
        '''
        print(f"Best parameters for iteration {i+1}:")
        for j, par in enumerate(curren_model_pars):
            print(f"Parameter {j+1}: {par.numpy():.4f}")
        '''

        if final_loss < min_loss:
            # Update best model parameters
            best_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
            min_loss = final_loss
            rf = r_factor_metric(labels, fun_tf(features, best_model_pars))
            print(f"Iteration {i+1} - New best loss: {min_loss:.3e} (R-factor: {rf:.3e})")

    if min_loss < best_rf_overall:
        best_rf_overall = min_loss
        best_pars_overall = best_model_pars
        best_loss_overall = all_losses
    print(f"time elapsed: {time() - time_start:.2f} seconds")
    print(f"With {n_epochs*n_iter /(time() - time_start)} iterations per second")
    # Plotting the loss values
    plt.figure(figsize=(10, 6))

    # Plot the loss values for each iteration
    for i, loss_values in enumerate(all_losses):
        plt.plot(loss_values, label=f'Iteration {i+1}')

    plt.title(f'Loss vs Epochs with Learning Rate {learning_rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    # plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# labels shape: (910, 1)
# labels_err shape: (910, 1)
# Learning rate: 0.0009
# max_mode_amps shape: (7,)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/1000
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 2s 2s/step - loss: 5.3760e-04 - r_factor_metric: 0.9950
# Epoch 2/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3719e-04 - r_factor_metric: 0.9948
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3678e-04 - r_factor_metric: 0.9946
# Epoch 4/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3637e-04 - r_factor_metric: 0.9945
# Epoch 5/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3596e-04 - r_factor_metric: 0.9943
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3555e-04 - r_factor_metric: 0.9941
# Epoch 7/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3515e-04 - r_factor_metric: 0.9940
# Epoch 8/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3476e-04 - r_factor_metric: 0.9939
# Epoch 9/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3437e-04 - r_factor_metric: 0.9937
# Epoch 10/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3398e-04 - r_factor_metric: 0.9936
# Epoch 11/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3360e-04 - r_factor_metric: 0.9935
# Epoch 12/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3322e-04 - r_factor_metric: 0.9934
# Epoch 13/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3284e-04 - r_factor_metric: 0.9932
# Epoch 14/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3247e-04 - r_factor_metric: 0.9931
# Epoch 15/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3211e-04 - r_factor_metric: 0.9930
# Epoch 16/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3175e-04 - r_factor_metric: 0.9929
# Epoch 17/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3139e-04 - r_factor_metric: 0.9928
# Epoch 18/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3104e-04 - r_factor_metric: 0.9927
# Epoch 19/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3069e-04 - r_factor_metric: 0.9926
# Epoch 20/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3035e-04 - r_factor_metric: 0.9925
# Epoch 21/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3001e-04 - r_factor_metric: 0.9924
# Epoch 22/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2968e-04 - r_factor_metric: 0.9924
# Epoch 23/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2935e-04 - r_factor_metric: 0.9923
# Epoch 24/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2903e-04 - r_factor_metric: 0.9923
# Epoch 25/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2871e-04 - r_factor_metric: 0.9922
# Epoch 26/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2840e-04 - r_factor_metric: 0.9921
# Epoch 27/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2809e-04 - r_factor_metric: 0.9921
# Epoch 28/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2779e-04 - r_factor_metric: 0.9920
# Epoch 29/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2749e-04 - r_factor_metric: 0.9920
# Epoch 30/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2719e-04 - r_factor_metric: 0.9919
# Epoch 31/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2690e-04 - r_factor_metric: 0.9918
# Epoch 32/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2662e-04 - r_factor_metric: 0.9918
# Epoch 33/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2634e-04 - r_factor_metric: 0.9918
# Epoch 34/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2606e-04 - r_factor_metric: 0.9917
# Epoch 35/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2579e-04 - r_factor_metric: 0.9917
# Epoch 36/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2552e-04 - r_factor_metric: 0.9917
# Epoch 37/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2526e-04 - r_factor_metric: 0.9916
# Epoch 38/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2500e-04 - r_factor_metric: 0.9916
# Epoch 39/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2475e-04 - r_factor_metric: 0.9915
# Epoch 40/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2450e-04 - r_factor_metric: 0.9915
# Epoch 41/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2425e-04 - r_factor_metric: 0.9914
# Epoch 42/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2401e-04 - r_factor_metric: 0.9914
# Epoch 43/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2377e-04 - r_factor_metric: 0.9913
# Epoch 44/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2353e-04 - r_factor_metric: 0.9913
# Epoch 45/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2330e-04 - r_factor_metric: 0.9912
# Epoch 46/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2308e-04 - r_factor_metric: 0.9912
# Epoch 47/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2285e-04 - r_factor_metric: 0.9911
# Epoch 48/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2263e-04 - r_factor_metric: 0.9911
# Epoch 49/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2242e-04 - r_factor_metric: 0.9911
# Epoch 50/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2220e-04 - r_factor_metric: 0.9910
# Epoch 51/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2199e-04 - r_factor_metric: 0.9910
# Epoch 52/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2179e-04 - r_factor_metric: 0.9909
# Epoch 53/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2158e-04 - r_factor_metric: 0.9909
# Epoch 54/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2138e-04 - r_factor_metric: 0.9908
# Epoch 55/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2119e-04 - r_factor_metric: 0.9907
# Epoch 56/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2099e-04 - r_factor_metric: 0.9907
# Epoch 57/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2080e-04 - r_factor_metric: 0.9906
# Epoch 58/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2061e-04 - r_factor_metric: 0.9905
# Epoch 59/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2043e-04 - r_factor_metric: 0.9905
# Epoch 60/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2025e-04 - r_factor_metric: 0.9904
# Epoch 61/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2007e-04 - r_factor_metric: 0.9903
# Epoch 62/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1989e-04 - r_factor_metric: 0.9902
# Epoch 63/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1971e-04 - r_factor_metric: 0.9902
# Epoch 64/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1954e-04 - r_factor_metric: 0.9901
# Epoch 65/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1937e-04 - r_factor_metric: 0.9900
# Epoch 66/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1920e-04 - r_factor_metric: 0.9899
# Epoch 67/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1904e-04 - r_factor_metric: 0.9898
# Epoch 68/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1887e-04 - r_factor_metric: 0.9897
# Epoch 69/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1871e-04 - r_factor_metric: 0.9896
# Epoch 70/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1855e-04 - r_factor_metric: 0.9895
# Epoch 71/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1840e-04 - r_factor_metric: 0.9895
# Epoch 72/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1824e-04 - r_factor_metric: 0.9894
# Epoch 73/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1809e-04 - r_factor_metric: 0.9893
# Epoch 74/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1794e-04 - r_factor_metric: 0.9892
# Epoch 75/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1779e-04 - r_factor_metric: 0.9891
# Epoch 76/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1764e-04 - r_factor_metric: 0.9890
# Epoch 77/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1749e-04 - r_factor_metric: 0.9889
# Epoch 78/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1735e-04 - r_factor_metric: 0.9888
# Epoch 79/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1721e-04 - r_factor_metric: 0.9888
# Epoch 80/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1707e-04 - r_factor_metric: 0.9887
# Epoch 81/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1693e-04 - r_factor_metric: 0.9886
# Epoch 82/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1679e-04 - r_factor_metric: 0.9885
# Epoch 83/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1665e-04 - r_factor_metric: 0.9884
# Epoch 84/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1652e-04 - r_factor_metric: 0.9883
# Epoch 85/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1639e-04 - r_factor_metric: 0.9882
# Epoch 86/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1625e-04 - r_factor_metric: 0.9881
# Epoch 87/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1612e-04 - r_factor_metric: 0.9880
# Epoch 88/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1599e-04 - r_factor_metric: 0.9879
# Epoch 89/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1587e-04 - r_factor_metric: 0.9878
# Epoch 90/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1574e-04 - r_factor_metric: 0.9877
# Epoch 91/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1562e-04 - r_factor_metric: 0.9876
# Epoch 92/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1549e-04 - r_factor_metric: 0.9875
# Epoch 93/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.1537e-04 - r_factor_metric: 0.9874
# Epoch 94/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1525e-04 - r_factor_metric: 0.9873
# Epoch 95/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1513e-04 - r_factor_metric: 0.9872
# Epoch 96/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1501e-04 - r_factor_metric: 0.9871
# Epoch 97/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1489e-04 - r_factor_metric: 0.9870
# Epoch 98/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1478e-04 - r_factor_metric: 0.9869
# Epoch 99/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1466e-04 - r_factor_metric: 0.9868
# Epoch 100/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1455e-04 - r_factor_metric: 0.9867
# Epoch 101/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1443e-04 - r_factor_metric: 0.9866
# Epoch 102/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1432e-04 - r_factor_metric: 0.9865
# Epoch 103/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1421e-04 - r_factor_metric: 0.9864
# Epoch 104/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1410e-04 - r_factor_metric: 0.9863
# Epoch 105/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1399e-04 - r_factor_metric: 0.9862
# Epoch 106/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1388e-04 - r_factor_metric: 0.9860
# Epoch 107/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1378e-04 - r_factor_metric: 0.9859
# Epoch 108/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1367e-04 - r_factor_metric: 0.9858
# Epoch 109/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1356e-04 - r_factor_metric: 0.9857
# Epoch 110/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1346e-04 - r_factor_metric: 0.9856
# Epoch 111/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1336e-04 - r_factor_metric: 0.9855
# Epoch 112/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1325e-04 - r_factor_metric: 0.9854
# Epoch 113/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1315e-04 - r_factor_metric: 0.9853
# Epoch 114/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1305e-04 - r_factor_metric: 0.9852
# Epoch 115/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1295e-04 - r_factor_metric: 0.9851
# Epoch 116/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1285e-04 - r_factor_metric: 0.9850
# Epoch 117/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1275e-04 - r_factor_metric: 0.9849
# Epoch 118/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1265e-04 - r_factor_metric: 0.9848
# Epoch 119/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1256e-04 - r_factor_metric: 0.9847
# Epoch 120/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1246e-04 - r_factor_metric: 0.9846
# Epoch 121/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1237e-04 - r_factor_metric: 0.9845
# Epoch 122/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1227e-04 - r_factor_metric: 0.9844
# Epoch 123/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1218e-04 - r_factor_metric: 0.9843
# Epoch 124/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1208e-04 - r_factor_metric: 0.9842
# Epoch 125/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1199e-04 - r_factor_metric: 0.9841
# Epoch 126/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.1190e-04 - r_factor_metric: 0.9840
# Epoch 127/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1181e-04 - r_factor_metric: 0.9839
# Epoch 128/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1172e-04 - r_factor_metric: 0.9838
# Epoch 129/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1162e-04 - r_factor_metric: 0.9837
# Epoch 130/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1154e-04 - r_factor_metric: 0.9836
# Epoch 131/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1145e-04 - r_factor_metric: 0.9835
# Epoch 132/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1136e-04 - r_factor_metric: 0.9835
# Epoch 133/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1127e-04 - r_factor_metric: 0.9834
# Epoch 134/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1118e-04 - r_factor_metric: 0.9833
# Epoch 135/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1110e-04 - r_factor_metric: 0.9832
# Epoch 136/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1101e-04 - r_factor_metric: 0.9831
# Epoch 137/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1092e-04 - r_factor_metric: 0.9830
# Epoch 138/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1084e-04 - r_factor_metric: 0.9829
# Epoch 139/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1075e-04 - r_factor_metric: 0.9828
# Epoch 140/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1067e-04 - r_factor_metric: 0.9827
# Epoch 141/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1059e-04 - r_factor_metric: 0.9827
# Epoch 142/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1050e-04 - r_factor_metric: 0.9826
# Epoch 143/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1042e-04 - r_factor_metric: 0.9825
# Epoch 144/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1034e-04 - r_factor_metric: 0.9824
# Epoch 145/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1026e-04 - r_factor_metric: 0.9823
# Epoch 146/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1018e-04 - r_factor_metric: 0.9822
# Epoch 147/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1010e-04 - r_factor_metric: 0.9821
# Epoch 148/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1002e-04 - r_factor_metric: 0.9820
# Epoch 149/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0994e-04 - r_factor_metric: 0.9819
# Epoch 150/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0986e-04 - r_factor_metric: 0.9818
# Epoch 151/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0978e-04 - r_factor_metric: 0.9818
# Epoch 152/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0970e-04 - r_factor_metric: 0.9817
# Epoch 153/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0962e-04 - r_factor_metric: 0.9816
# Epoch 154/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0955e-04 - r_factor_metric: 0.9815
# Epoch 155/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0947e-04 - r_factor_metric: 0.9814
# Epoch 156/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0939e-04 - r_factor_metric: 0.9813
# Epoch 157/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0932e-04 - r_factor_metric: 0.9812
# Epoch 158/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0924e-04 - r_factor_metric: 0.9811
# Epoch 159/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0917e-04 - r_factor_metric: 0.9810
# Epoch 160/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0909e-04 - r_factor_metric: 0.9809
# Epoch 161/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0902e-04 - r_factor_metric: 0.9808
# Epoch 162/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0894e-04 - r_factor_metric: 0.9807
# Epoch 163/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0887e-04 - r_factor_metric: 0.9806
# Epoch 164/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0880e-04 - r_factor_metric: 0.9805
# Epoch 165/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0872e-04 - r_factor_metric: 0.9804
# Epoch 166/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0865e-04 - r_factor_metric: 0.9803
# Epoch 167/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0858e-04 - r_factor_metric: 0.9802
# Epoch 168/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0851e-04 - r_factor_metric: 0.9801
# Epoch 169/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 5.0844e-04 - r_factor_metric: 0.9800
# Epoch 170/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 5.0836e-04 - r_factor_metric: 0.9799
# Epoch 171/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0829e-04 - r_factor_metric: 0.9798
# Epoch 172/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0822e-04 - r_factor_metric: 0.9798
# Epoch 173/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0815e-04 - r_factor_metric: 0.9797
# Epoch 174/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0808e-04 - r_factor_metric: 0.9796
# Epoch 175/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0801e-04 - r_factor_metric: 0.9795
# Epoch 176/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0795e-04 - r_factor_metric: 0.9794
# Epoch 177/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0788e-04 - r_factor_metric: 0.9793
# Epoch 178/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0781e-04 - r_factor_metric: 0.9792
# Epoch 179/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0774e-04 - r_factor_metric: 0.9791
# Epoch 180/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0767e-04 - r_factor_metric: 0.9790
# Epoch 181/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0760e-04 - r_factor_metric: 0.9789
# Epoch 182/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0754e-04 - r_factor_metric: 0.9788
# Epoch 183/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0747e-04 - r_factor_metric: 0.9787
# Epoch 184/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0740e-04 - r_factor_metric: 0.9786
# Epoch 185/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0734e-04 - r_factor_metric: 0.9785
# Epoch 186/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0727e-04 - r_factor_metric: 0.9784
# Epoch 187/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0721e-04 - r_factor_metric: 0.9783
# Epoch 188/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0714e-04 - r_factor_metric: 0.9782
# Epoch 189/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0708e-04 - r_factor_metric: 0.9781
# Epoch 190/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0701e-04 - r_factor_metric: 0.9781
# Epoch 191/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0695e-04 - r_factor_metric: 0.9780
# Epoch 192/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0688e-04 - r_factor_metric: 0.9779
# Epoch 193/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0682e-04 - r_factor_metric: 0.9778
# Epoch 194/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0675e-04 - r_factor_metric: 0.9777
# Epoch 195/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0669e-04 - r_factor_metric: 0.9776
# Epoch 196/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0663e-04 - r_factor_metric: 0.9775
# Epoch 197/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0656e-04 - r_factor_metric: 0.9774
# Epoch 198/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0650e-04 - r_factor_metric: 0.9773
# Epoch 199/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0644e-04 - r_factor_metric: 0.9772
# Epoch 200/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0638e-04 - r_factor_metric: 0.9771
# Epoch 201/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0632e-04 - r_factor_metric: 0.9770
# Epoch 202/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0625e-04 - r_factor_metric: 0.9769
# Epoch 203/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0619e-04 - r_factor_metric: 0.9768
# Epoch 204/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0613e-04 - r_factor_metric: 0.9767
# Epoch 205/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0607e-04 - r_factor_metric: 0.9766
# Epoch 206/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0601e-04 - r_factor_metric: 0.9765
# Epoch 207/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0595e-04 - r_factor_metric: 0.9764
# Epoch 208/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0589e-04 - r_factor_metric: 0.9763
# Epoch 209/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0583e-04 - r_factor_metric: 0.9762
# Epoch 210/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0577e-04 - r_factor_metric: 0.9761
# Epoch 211/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0571e-04 - r_factor_metric: 0.9760
# Epoch 212/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0565e-04 - r_factor_metric: 0.9759
# Epoch 213/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0559e-04 - r_factor_metric: 0.9758
# Epoch 214/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0553e-04 - r_factor_metric: 0.9757
# Epoch 215/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0547e-04 - r_factor_metric: 0.9756
# Epoch 216/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0542e-04 - r_factor_metric: 0.9755
# Epoch 217/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0536e-04 - r_factor_metric: 0.9754
# Epoch 218/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0530e-04 - r_factor_metric: 0.9754
# Epoch 219/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0524e-04 - r_factor_metric: 0.9753
# Epoch 220/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0519e-04 - r_factor_metric: 0.9752
# Epoch 221/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0513e-04 - r_factor_metric: 0.9751
# Epoch 222/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0507e-04 - r_factor_metric: 0.9750
# Epoch 223/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0501e-04 - r_factor_metric: 0.9749
# Epoch 224/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0496e-04 - r_factor_metric: 0.9748
# Epoch 225/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0490e-04 - r_factor_metric: 0.9748
# Epoch 226/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0485e-04 - r_factor_metric: 0.9747
# Epoch 227/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0479e-04 - r_factor_metric: 0.9746
# Epoch 228/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0473e-04 - r_factor_metric: 0.9745
# Epoch 229/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0468e-04 - r_factor_metric: 0.9744
# Epoch 230/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0462e-04 - r_factor_metric: 0.9743
# Epoch 231/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0457e-04 - r_factor_metric: 0.9742
# Epoch 232/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0451e-04 - r_factor_metric: 0.9742
# Epoch 233/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0446e-04 - r_factor_metric: 0.9741
# Epoch 234/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0440e-04 - r_factor_metric: 0.9740
# Epoch 235/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 5.0435e-04 - r_factor_metric: 0.9739
# Epoch 236/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0429e-04 - r_factor_metric: 0.9738
# Epoch 237/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.0424e-04 - r_factor_metric: 0.9737
# Epoch 238/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0419e-04 - r_factor_metric: 0.9736
# Epoch 239/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0413e-04 - r_factor_metric: 0.9735
# Epoch 240/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0408e-04 - r_factor_metric: 0.9734
# Epoch 241/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0403e-04 - r_factor_metric: 0.9733
# Epoch 242/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0397e-04 - r_factor_metric: 0.9733
# Epoch 243/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0392e-04 - r_factor_metric: 0.9732
# Epoch 244/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0387e-04 - r_factor_metric: 0.9731
# Epoch 245/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0381e-04 - r_factor_metric: 0.9730
# Epoch 246/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0376e-04 - r_factor_metric: 0.9729
# Epoch 247/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0371e-04 - r_factor_metric: 0.9728
# Epoch 248/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0366e-04 - r_factor_metric: 0.9727
# Epoch 249/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0361e-04 - r_factor_metric: 0.9726
# Epoch 250/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0355e-04 - r_factor_metric: 0.9725
# Epoch 251/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0350e-04 - r_factor_metric: 0.9725
# Epoch 252/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0345e-04 - r_factor_metric: 0.9724
# Epoch 253/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0340e-04 - r_factor_metric: 0.9723
# Epoch 254/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0335e-04 - r_factor_metric: 0.9722
# Epoch 255/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 5.0330e-04 - r_factor_metric: 0.9721
# Epoch 256/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 5.0325e-04 - r_factor_metric: 0.9720
# Epoch 257/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0320e-04 - r_factor_metric: 0.9719
# Epoch 258/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0315e-04 - r_factor_metric: 0.9719
# Epoch 259/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0310e-04 - r_factor_metric: 0.9718
# Epoch 260/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0305e-04 - r_factor_metric: 0.9717
# Epoch 261/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0300e-04 - r_factor_metric: 0.9716
# Epoch 262/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0295e-04 - r_factor_metric: 0.9715
# Epoch 263/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0290e-04 - r_factor_metric: 0.9715
# Epoch 264/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0285e-04 - r_factor_metric: 0.9714
# Epoch 265/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0280e-04 - r_factor_metric: 0.9713
# Epoch 266/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0275e-04 - r_factor_metric: 0.9713
# Epoch 267/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0270e-04 - r_factor_metric: 0.9712
# Epoch 268/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0265e-04 - r_factor_metric: 0.9711
# Epoch 269/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0260e-04 - r_factor_metric: 0.9711
# Epoch 270/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0256e-04 - r_factor_metric: 0.9710
# Epoch 271/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0251e-04 - r_factor_metric: 0.9709
# Epoch 272/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0246e-04 - r_factor_metric: 0.9708
# Epoch 273/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0241e-04 - r_factor_metric: 0.9708
# Epoch 274/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0236e-04 - r_factor_metric: 0.9707
# Epoch 275/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0232e-04 - r_factor_metric: 0.9706
# Epoch 276/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0227e-04 - r_factor_metric: 0.9706
# Epoch 277/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0222e-04 - r_factor_metric: 0.9705
# Epoch 278/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0217e-04 - r_factor_metric: 0.9704
# Epoch 279/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0213e-04 - r_factor_metric: 0.9704
# Epoch 280/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0208e-04 - r_factor_metric: 0.9703
# Epoch 281/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0203e-04 - r_factor_metric: 0.9702
# Epoch 282/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0199e-04 - r_factor_metric: 0.9702
# Epoch 283/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0194e-04 - r_factor_metric: 0.9701
# Epoch 284/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0189e-04 - r_factor_metric: 0.9701
# Epoch 285/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0185e-04 - r_factor_metric: 0.9700
# Epoch 286/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0180e-04 - r_factor_metric: 0.9700
# Epoch 287/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0176e-04 - r_factor_metric: 0.9699
# Epoch 288/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0171e-04 - r_factor_metric: 0.9698
# Epoch 289/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0166e-04 - r_factor_metric: 0.9698
# Epoch 290/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0162e-04 - r_factor_metric: 0.9697
# Epoch 291/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0157e-04 - r_factor_metric: 0.9697
# Epoch 292/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0153e-04 - r_factor_metric: 0.9696
# Epoch 293/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0148e-04 - r_factor_metric: 0.9695
# Epoch 294/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0144e-04 - r_factor_metric: 0.9695
# Epoch 295/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0139e-04 - r_factor_metric: 0.9694
# Epoch 296/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0135e-04 - r_factor_metric: 0.9694
# Epoch 297/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0130e-04 - r_factor_metric: 0.9693
# Epoch 298/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0126e-04 - r_factor_metric: 0.9692
# Epoch 299/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0121e-04 - r_factor_metric: 0.9692
# Epoch 300/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0117e-04 - r_factor_metric: 0.9691
# Epoch 301/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0113e-04 - r_factor_metric: 0.9690
# Epoch 302/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0108e-04 - r_factor_metric: 0.9690
# Epoch 303/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0104e-04 - r_factor_metric: 0.9689
# Epoch 304/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0099e-04 - r_factor_metric: 0.9689
# Epoch 305/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0095e-04 - r_factor_metric: 0.9688
# Epoch 306/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0091e-04 - r_factor_metric: 0.9687
# Epoch 307/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0086e-04 - r_factor_metric: 0.9687
# Epoch 308/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0082e-04 - r_factor_metric: 0.9686
# Epoch 309/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0078e-04 - r_factor_metric: 0.9686
# Epoch 310/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0074e-04 - r_factor_metric: 0.9685
# Epoch 311/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0069e-04 - r_factor_metric: 0.9684
# Epoch 312/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0065e-04 - r_factor_metric: 0.9684
# Epoch 313/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0061e-04 - r_factor_metric: 0.9683
# Epoch 314/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0056e-04 - r_factor_metric: 0.9682
# Epoch 315/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0052e-04 - r_factor_metric: 0.9682
# Epoch 316/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0048e-04 - r_factor_metric: 0.9681
# Epoch 317/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0044e-04 - r_factor_metric: 0.9680
# Epoch 318/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0040e-04 - r_factor_metric: 0.9680
# Epoch 319/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0035e-04 - r_factor_metric: 0.9679
# Epoch 320/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0031e-04 - r_factor_metric: 0.9678
# Epoch 321/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0027e-04 - r_factor_metric: 0.9678
# Epoch 322/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0023e-04 - r_factor_metric: 0.9677
# Epoch 323/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0019e-04 - r_factor_metric: 0.9676
# Epoch 324/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0015e-04 - r_factor_metric: 0.9675
# Epoch 325/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0011e-04 - r_factor_metric: 0.9675
# Epoch 326/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0006e-04 - r_factor_metric: 0.9674
# Epoch 327/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0002e-04 - r_factor_metric: 0.9673
# Epoch 328/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9998e-04 - r_factor_metric: 0.9672
# Epoch 329/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9994e-04 - r_factor_metric: 0.9672
# Epoch 330/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 4.9990e-04 - r_factor_metric: 0.9671
# Epoch 331/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9986e-04 - r_factor_metric: 0.9670
# Epoch 332/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9982e-04 - r_factor_metric: 0.9669
# Epoch 333/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9978e-04 - r_factor_metric: 0.9669
# Epoch 334/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9974e-04 - r_factor_metric: 0.9668
# Epoch 335/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9970e-04 - r_factor_metric: 0.9667
# Epoch 336/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.9966e-04 - r_factor_metric: 0.9666
# Epoch 337/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9962e-04 - r_factor_metric: 0.9666
# Epoch 338/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9958e-04 - r_factor_metric: 0.9665
# Epoch 339/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9954e-04 - r_factor_metric: 0.9664
# Epoch 340/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9950e-04 - r_factor_metric: 0.9663
# Epoch 341/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9946e-04 - r_factor_metric: 0.9663
# Epoch 342/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9942e-04 - r_factor_metric: 0.9662
# Epoch 343/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9938e-04 - r_factor_metric: 0.9661
# Epoch 344/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9935e-04 - r_factor_metric: 0.9660
# Epoch 345/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9931e-04 - r_factor_metric: 0.9659
# Epoch 346/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9927e-04 - r_factor_metric: 0.9659
# Epoch 347/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9923e-04 - r_factor_metric: 0.9658
# Epoch 348/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9919e-04 - r_factor_metric: 0.9657
# Epoch 349/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9915e-04 - r_factor_metric: 0.9656
# Epoch 350/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9911e-04 - r_factor_metric: 0.9656
# Epoch 351/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9908e-04 - r_factor_metric: 0.9655
# Epoch 352/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9904e-04 - r_factor_metric: 0.9654
# Epoch 353/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 4.9900e-04 - r_factor_metric: 0.9654
# Epoch 354/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 4.9896e-04 - r_factor_metric: 0.9653
# Epoch 355/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9892e-04 - r_factor_metric: 0.9652
# Epoch 356/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9889e-04 - r_factor_metric: 0.9652
# Epoch 357/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9885e-04 - r_factor_metric: 0.9651
# Epoch 358/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9881e-04 - r_factor_metric: 0.9651
# Epoch 359/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9877e-04 - r_factor_metric: 0.9650
# Epoch 360/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9874e-04 - r_factor_metric: 0.9649
# Epoch 361/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9870e-04 - r_factor_metric: 0.9649
# Epoch 362/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9866e-04 - r_factor_metric: 0.9648
# Epoch 363/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9863e-04 - r_factor_metric: 0.9648
# Epoch 364/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9859e-04 - r_factor_metric: 0.9647
# Epoch 365/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9855e-04 - r_factor_metric: 0.9647
# Epoch 366/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9852e-04 - r_factor_metric: 0.9646
# Epoch 367/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9848e-04 - r_factor_metric: 0.9645
# Epoch 368/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9844e-04 - r_factor_metric: 0.9645
# Epoch 369/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9841e-04 - r_factor_metric: 0.9644
# Epoch 370/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9837e-04 - r_factor_metric: 0.9644
# Epoch 371/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9834e-04 - r_factor_metric: 0.9643
# Epoch 372/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9830e-04 - r_factor_metric: 0.9642
# Epoch 373/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9826e-04 - r_factor_metric: 0.9642
# Epoch 374/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9823e-04 - r_factor_metric: 0.9641
# Epoch 375/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9819e-04 - r_factor_metric: 0.9641
# Epoch 376/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9816e-04 - r_factor_metric: 0.9640
# Epoch 377/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9812e-04 - r_factor_metric: 0.9639
# Epoch 378/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9809e-04 - r_factor_metric: 0.9639
# Epoch 379/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9805e-04 - r_factor_metric: 0.9638
# Epoch 380/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9802e-04 - r_factor_metric: 0.9638
# Epoch 381/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9798e-04 - r_factor_metric: 0.9637
# Epoch 382/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9795e-04 - r_factor_metric: 0.9637
# Epoch 383/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9791e-04 - r_factor_metric: 0.9636
# Epoch 384/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 4.9788e-04 - r_factor_metric: 0.9635
# Epoch 385/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9784e-04 - r_factor_metric: 0.9635
# Epoch 386/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9781e-04 - r_factor_metric: 0.9634
# Epoch 387/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9778e-04 - r_factor_metric: 0.9634
# Epoch 388/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9774e-04 - r_factor_metric: 0.9633
# Epoch 389/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9771e-04 - r_factor_metric: 0.9633
# Epoch 390/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9767e-04 - r_factor_metric: 0.9632
# Epoch 391/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9764e-04 - r_factor_metric: 0.9632
# Epoch 392/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9761e-04 - r_factor_metric: 0.9631
# Epoch 393/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9757e-04 - r_factor_metric: 0.9631
# Epoch 394/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9754e-04 - r_factor_metric: 0.9630
# Epoch 395/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9751e-04 - r_factor_metric: 0.9629
# Epoch 396/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9747e-04 - r_factor_metric: 0.9629
# Epoch 397/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9744e-04 - r_factor_metric: 0.9628
# Epoch 398/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9741e-04 - r_factor_metric: 0.9628
# Epoch 399/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9737e-04 - r_factor_metric: 0.9627
# Epoch 400/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9734e-04 - r_factor_metric: 0.9627
# Epoch 401/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9731e-04 - r_factor_metric: 0.9626
# Epoch 402/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9728e-04 - r_factor_metric: 0.9626
# Epoch 403/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9724e-04 - r_factor_metric: 0.9625
# Epoch 404/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9721e-04 - r_factor_metric: 0.9625
# Epoch 405/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9718e-04 - r_factor_metric: 0.9624
# Epoch 406/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9715e-04 - r_factor_metric: 0.9624
# Epoch 407/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9711e-04 - r_factor_metric: 0.9623
# Epoch 408/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9708e-04 - r_factor_metric: 0.9623
# Epoch 409/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9705e-04 - r_factor_metric: 0.9622
# Epoch 410/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9702e-04 - r_factor_metric: 0.9622
# Epoch 411/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9699e-04 - r_factor_metric: 0.9621
# Epoch 412/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9696e-04 - r_factor_metric: 0.9621
# Epoch 413/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9692e-04 - r_factor_metric: 0.9620
# Epoch 414/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9689e-04 - r_factor_metric: 0.9620
# Epoch 415/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9686e-04 - r_factor_metric: 0.9619
# Epoch 416/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9683e-04 - r_factor_metric: 0.9619
# Epoch 417/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9680e-04 - r_factor_metric: 0.9618
# Epoch 418/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9677e-04 - r_factor_metric: 0.9618
# Epoch 419/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9674e-04 - r_factor_metric: 0.9617
# Epoch 420/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9671e-04 - r_factor_metric: 0.9616
# Epoch 421/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9668e-04 - r_factor_metric: 0.9616
# Epoch 422/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9665e-04 - r_factor_metric: 0.9615
# Epoch 423/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9662e-04 - r_factor_metric: 0.9615
# Epoch 424/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9659e-04 - r_factor_metric: 0.9614
# Epoch 425/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9656e-04 - r_factor_metric: 0.9614
# Epoch 426/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9653e-04 - r_factor_metric: 0.9613
# Epoch 427/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9650e-04 - r_factor_metric: 0.9613
# Epoch 428/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9647e-04 - r_factor_metric: 0.9612
# Epoch 429/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9644e-04 - r_factor_metric: 0.9612
# ...
# Epoch 858/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 859/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 860/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 861/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 862/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 863/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 864/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 865/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 866/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 867/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 868/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 869/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 5.3016e-04 - r_factor_metric: 0.9812
# Epoch 870/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 871/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 872/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 873/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 874/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 875/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 876/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 877/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 878/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 879/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 880/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 881/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 882/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 883/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 884/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 885/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 886/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 887/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 888/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 889/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 890/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 891/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 892/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 893/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 894/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 895/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 896/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 897/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 898/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 899/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 900/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 901/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 902/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 903/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 904/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 905/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 906/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 907/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 908/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 909/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 910/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3015e-04 - r_factor_metric: 0.9812
# Epoch 911/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 912/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 913/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 914/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 915/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 916/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 917/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 918/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 919/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 920/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 921/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 922/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 923/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 924/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 925/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 926/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 927/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 928/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 929/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 930/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 931/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 932/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 933/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 934/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 935/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 936/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 937/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 938/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 939/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 940/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 941/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 942/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 943/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 944/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9812
# Epoch 945/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 946/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 947/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 948/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 949/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 950/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 951/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 952/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 953/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 954/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 955/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 956/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 957/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 958/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 959/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 960/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 961/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 962/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 963/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 964/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 965/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 966/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3014e-04 - r_factor_metric: 0.9813
# Epoch 967/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 968/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 969/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 970/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 971/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 972/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 973/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 974/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 975/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 976/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 977/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 978/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 979/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 980/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 981/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 982/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 983/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 984/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 985/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 986/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 987/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 988/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 989/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 990/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 991/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 992/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 993/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 994/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 995/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 996/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 997/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 998/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 999/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# Epoch 1000/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3013e-04 - r_factor_metric: 0.9813
# (7,)
# Final loss: 5.301e-04
# time elapsed: 35.18 seconds
# With 56.84825473903239 iterations per second

# %%
all_losses = best_loss_overall
best_model_pars = best_pars_overall
min_loss = best_rf_overall

print(f"min loss: {min_loss}")


# Plotting the loss values
plt.figure(figsize=(10, 6))

# Plot the loss values for each iteration
for i, loss_values in enumerate(all_losses):
    plt.plot(loss_values, label=f'Iteration {i+1}')

plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.grid(True)
plt.show()
# Out:
# min loss: 0.0004905876121483743

# %%
mode_names = pd.read_csv('P3/raw_data/PrNiO2_displacivemode_names.txt' , delim_whitespace=True, header=None)
mode_names = mode_names.values.tolist()
mode_names = pd.DataFrame(mode_names)


# Print the best model parameters
print("Best model parameters:") 
for i, par in enumerate(best_model_pars):
    print(f"mode a{i+1} {mode_names.iloc[i, 0]} : {par.numpy():.8f}")
    
# Print the model summary
print("Number of iterations:", n_iter)
print("Number of features:", n_features)
model.summary()
#modes = get_mode_amplitudes_p63(*best_model_pars)
#print("Modes:")
##for key, val in modes.items():
    #print(f"{key}: {val*1000:.4f}")
# Out:
# Best model parameters:
# mode a1 [1/4,1/4,1/2]S1(a,0;a,0)[Pr1:d:dsp]A2u(a) : -2.04818678
# mode a2 [0,1/2,0]X1+(a;a)[Pr1:d:dsp]Eu(a) : 0.11003178
# mode a3 [1/4,1/4,1/2]S1(a,0;a,0)[O1:f:dsp]B3u(a) : -2.35946202
# mode a4 [1/4,1/4,1/2]S1(a,0;a,0)[O1:f:dsp]B2u(a) : 0.37095529
# mode a5 [1/2,1/2,0]M1+(a)[O1:f:dsp]B2u(a) : -2.48930287
# mode a6 [0,1/2,0]X1+(a;a)[O1:f:dsp]B2u(a) : -0.03493906
# mode a7 [1/4,1/4,1/2]S1(a,0;a,0)[Ni1:a:dsp]Eu(a) : -1.44075048
# Number of iterations: 2
# Number of features: 910
# Model: "model_118"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_120 (InputLayer)      [(None, 3)]               0
#
#  fun_as_layer_119 (FunAsLaye  (None,)                  7
#  r)
#
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\User\AppData\Local\Temp\ipykernel_7628\3631840648.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mode_names = pd.read_csv('raw_data/PrNiO2_displacivemode_names.txt' , delim_whitespace=True, header=None)

# %%
def plot_plane_sim_vs_exp(ax, df, l, norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.max(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.max(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_sim'] * 300, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="left"))
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_exp'] * 300, color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="right"))
    
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    ax.set_title(f"l = {l}")
    ax.legend()

# %%
exp_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/raw_data/combined.csv')
exp_data['intensity_sim'] = fun_tf(features, best_model_pars).numpy()
# Out:
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)

# %%
# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], exp_data, l, norm_plane=True)

plt.show()

# %%
#save the experiment data with simulated intensities
exp_data.to_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt', index=False)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_parameters_and_modes.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars):
        f.write(f"{mode_names.iloc[i, 0]} : {par.numpy():.8f} \n")

abs_params = tf.abs(best_model_pars)
best_model_pars_compare = best_model_pars.numpy()
best_model_pars_compare = best_model_pars_compare / np.max(best_model_pars_compare)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_parameters_and_modes_normalised.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars_compare):
        f.write(f"{mode_names.iloc[i, 1]} : {par:.8f} \n")

# %%
best_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt')


# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], best_data, l, norm_plane=True)

plt.show()
