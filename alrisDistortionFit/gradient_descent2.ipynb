# %% [markdown]
# # Pr-YBCO version Fit modes

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from alris_functions2 import shift_atoms, transform_list_hkl_p63_p65, get_structure_factors , atom_position_list
from itertools import chain
from matplotlib.markers import MarkerStyle
from tqdm import tqdm
from time import time

# %config InlineBackend.figure_format = 'svg' # make figures appears in .svg style




num_threads = 2  

# Configure TensorFlow to use multiple threads
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.threading.set_inter_op_parallelism_threads(num_threads)

print(f"Using {num_threads} threads for intra-op and inter-op parallelism.")
# Out:
# Using 2 threads for intra-op and inter-op parallelism.

# %% [markdown]
# Define the function containing the fitting parameters
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - `fun_tf()` correspond to the **structure factor calculation function** (one has to convert it to a **TF-compatible** function)
# - <span style="color:red">If conversion to TF-compatible function is not possible, then this approach will probably not work (or becomes much more tedious at least)</span>

# %%
#convert the simulated data to log10 scale

def log10(x):
  numerator = tf.math.log(x)
  denominator = tf.math.log(tf.constant(10, dtype=numerator.dtype))
  return numerator / denominator

# %%
def fun_tf(x, pars):
    """
    Fast computation of structure factors with parameter-dependent structure.
        # Get modified structure
    modified_struct = shift_atoms_p65(*pars)
    neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    sf_neg_k = sf_combined[tf.shape(x)[0]:]
    
    intensity = (tf.abs(sf_hkl) + tf.abs(sf_neg_k)) ** 2
    return intensity / tf.reduce_max(intensity)
    """
    # Get modified structure
    atom_shift_list = shift_atoms(*pars)
    print(f"Shape of atom_shift_list: {len(atom_shift_list)}")



    # Flatten atom_shift_list if it contains nested lists
    flat_atom_shift_list = list(chain.from_iterable(
        x if isinstance(x, list) else [x] for x in atom_shift_list
    ))
    modified_struct = atom_position_list(*flat_atom_shift_list)

    #neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = x
    #x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    
    print(f"Shape of sf_combined: {sf_combined.shape}, Shape of x_combined: {x_combined.shape}")
    
    intensity = (tf.abs(sf_hkl)) ** 2
    w = tf.constant(0.00159, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    qnorms = tf.norm(tf.cast(x_combined[:tf.shape(x)[0]], tf.float32), axis=1)
    # qnorms = tf.reshape(qnorms, (-1, 1))  # Reshape to match the shape of intensity
    intensity = intensity * tf.exp(-w * qnorms ** 2)  # Apply Debye-Waller factor
    intensity = log10(intensity + 1)  # Convert to log10 scale
    return intensity / tf.reduce_max(intensity)

# %%
experimental_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/raw_data/peaks1.csv')
"""
# reduce data to l in [0.5, 1.5, 2.5, 3.5, 4.5 ]
experimental_data = experimental_data[
    (experimental_data["l"] == 0.5) |
    (experimental_data["l"] == 1.5) |
    (experimental_data["l"] == 2.5) |
    (experimental_data["l"] == 3.5) |
    (experimental_data["l"] == 4.5)
]
"""

hkl_list = experimental_data[["h", "k", "l"]].values.tolist()
hkl_list = tf.convert_to_tensor(hkl_list, dtype=tf.float32)
print(experimental_data.shape)
print(hkl_list[0:8])
# Out:
# (217, 5)
# tf.Tensor(
# [[0.        1.1111112 0.       ]
#  [0.        1.2222222 0.       ]
#  [0.        1.3333334 0.       ]
#  [0.        1.4444444 0.       ]
#  [0.        1.5555556 0.       ]
#  [0.        1.6666666 0.       ]
#  [0.        1.7777778 0.       ]
#  [0.        1.8888888 0.       ]], shape=(8, 3), dtype=float32)

# %% [markdown]
# Sample the "training data" (features and labels)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The features are the (h,k,l) coordinates (e.g. a vector of size `n_features` x 3, i.e. `n_dim = 3`)
# - Maybe one has to normalize the features (i.e. not using integers but floats between -1 (0) and 1)? Before passing them to the structure calculation function, they should be again rescaled to integers
# - The labels would be the experimental intensities (again, maybe have to be normalized to the range between 0 and 1)

# %%
n_features = experimental_data.shape[0]
n_dim = 3

features = hkl_list
labels = experimental_data["intensity_exp"].tolist()
#labels = tf.convert_to_tensor(labels, dtype=tf.float32)

vol_err = experimental_data["intensity_exp_err"].tolist()
labels_err = []
for label, err in zip(labels, vol_err):
    
    labels_err.append(np.sqrt(label))  # Inverse error

labels = labels / np.max(labels)  # Normalize labels

labels_err = tf.convert_to_tensor(labels_err, dtype=tf.float32)
labels = tf.convert_to_tensor(labels, dtype=tf.float32)

labels = tf.expand_dims(labels, axis=-1)  # Ensure labels are 2D
labels_err = tf.expand_dims(labels_err, axis=-1)  # Ensure labels_err are 2D

print("Max label err:", np.max(labels_err))
print("min label err:", np.min(labels_err))
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print('error shape:', labels_err.shape)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))
# Out:
# Max label err: 1.2363877
# min label err: 0.12145521
# Features shape: (217, 3)
# Labels shape: (217, 1)
# error shape: (217, 1)
# Max label: 1.0
# min label : 0.009649902

# %% [markdown]
# Define a simple model
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The six parameters (a,b,c,d,e,f) correspond to the fractional atomic shifts in the modes w.r.t. unit cell lengths
# - Instead of `sigmoid`, `tanh` should be applied to the parameters before passing them to the structure factor calculation function (ensures smoother gradient landscape)
# - The `tanh` function can furthermore be limited to a specific range (e.g. if atomic distortions should not exceed +- 0.1)

# %%
class FunAsLayer(tf.keras.layers.Layer):
    def __init__(self, max_mode_amps,**kwargs):
        super().__init__(**kwargs)
        self.max_mode_amps = max_mode_amps

    def build(self, input_shape):
        self.param = self.add_weight(name='param', shape=(445,), initializer=tf.keras.initializers.he_uniform(), trainable=True)
        super().build(input_shape)

    def call(self, inputs):
        # Apply tanh to ensure parameters stay within the [-1, 1] range then multiply by max_mode_amps so each parameter is scaled corresponding to the element in max_mode_amps
        pretransform = tf.tanh(self.param)
        transformed_params = pretransform * self.max_mode_amps  # Scale parameters

        output = fun_tf(inputs, tf.unstack(transformed_params))
        return tf.reshape(output , [-1])  # Ensure output is 1D

# %% [markdown]
# Create optimizer and define loss function
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The learning rate must be determined by experimentation (same holds for the batch size and the number of epochs below)
# - As a loss function, one can try either MSE or R-score (MSE seems to be the more "natural choice" in this case)

# %%
"""
# R-Score based on intensity
class RFactorLoss(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        return tf.reduce_sum(tf.abs(y_true - y_pred)) / tf.reduce_sum(y_true)
"""
    
# mean squared error
class PerSampleMSE(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__(reduction=tf.keras.losses.Reduction.NONE)

    def call(self, y_true, y_pred):
        squared_error = tf.square(y_true - y_pred)
        per_sample_mse = tf.reduce_mean(squared_error, axis=-1)
        return per_sample_mse  # shape (batch_size,)

class MSE_weighted(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        # Assume y_true = [labels, errors]
        print('ytrue shape:', y_true.shape)
        print('y true' , y_true)
        labels = y_true[:, 0]
        weights = y_true[:, 1]

        mse = tf.square(labels - y_pred)
        return tf.reduce_sum(mse * weights) / tf.reduce_sum(weights)


# Define the custom metric function
def r_factor_metric(y_true, y_pred):
    labels = y_true
    return tf.reduce_sum(tf.abs(labels - y_pred)) / tf.reduce_sum(labels)

# %% [markdown]
# Train the model for n iterations (to try different initial weights)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The number of iterations defines the "starting position" $w_0$ of the gradient descent algorithm
# - Because there are probably many local minima, changing $w_0$ allows the algorithm to find different minima and increases the chances of finding the global minima

# %%
#squeeze labels and labels_err to ensure they are 1D tensors
#labels = tf.squeeze(labels)
#labels_err = tf.squeeze(labels_err)

print("labels shape:", labels.shape)
print("labels_err shape:", labels_err.shape)


lr = [8e-4]
best_pars_overall = None
best_rf_overall = np.inf
best_loss_overall = []
for learning_rate in lr:
    time_start = time()
    print(f"Learning rate: {learning_rate}")
    optim = tf.keras.optimizers.Adam(learning_rate=learning_rate)


    max_mode_amps = tf.constant([4.57,4.57,6.46,6.46,7.35,6.46,6.46,6.46,7.35,6.46,4.57,4.57,4.57,5.2,4.57,4.57,4.57,4.57,4.57,4.57,4.57,5.2,4.57,4.57,5.2,4.57,5.2,4.57,5.2,5.2,5.2,4.57,4.57,4.57,4.57,4.57,4.57,5.2,4.57,4.57,6.36,6.46,6.46,12.73,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,7.35,6.36,6.46,7.35,6.36,7.35,7.35,6.36,6.46,7.35,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,4.57,4.57,6.46,6.46,7.35,6.46,6.46,6.46,7.35,6.46,4.57,4.57,4.57,5.2,4.57,4.57,4.57,4.57,4.57,4.57,4.57,5.2,4.57,4.57,5.2,4.57,5.2,4.57,5.2,5.2,5.2,4.57,4.57,4.57,4.57,4.57,4.57,5.2,4.57,4.57,6.36,6.46,6.46,12.73,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,7.35,6.36,6.46,7.35,6.36,7.35,7.35,6.36,6.46,7.35,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,4.57,4.57,6.46,6.46,7.35,6.46,6.46,6.46,7.35,6.46,4.57,4.57,4.57,5.2,4.57,4.57,4.57,4.57,4.57,4.57,4.57,5.2,4.57,4.57,5.2,4.57,5.2,4.57,5.2,5.2,5.2,4.57,4.57,4.57,4.57,4.57,4.57,5.2,4.57,4.57,6.36,6.46,6.46,12.73,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,7.35,6.36,6.46,7.35,6.36,7.35,7.35,6.36,6.46,7.35,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,12.73,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,7.35,6.36,6.46,7.35,6.36,7.35,7.35,6.36,6.46,7.35,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,12.73,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,9.0,9.14,9.0,9.14,9.0,10.39,9.0,9.14,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46,6.36,6.46,7.35,6.36,6.46,7.35,6.36,7.35,7.35,6.36,6.46,7.35,6.36,6.46,6.46,6.36,6.46,6.46,6.36,7.35,6.46,6.36,6.46,6.46] , dtype=tf.float32)
    print("max_mode_amps shape:", max_mode_amps.shape)

    n_epochs = 2000
    histories = []
    n_iter = 2

    min_loss = np.inf
    best_pars = None

    # List to store the loss values for each epoch
    all_losses = []


    for i in range(n_iter):
        # Create the model
        inputs = tf.keras.Input(shape=(n_dim,))
        outputs = FunAsLayer(max_mode_amps)(inputs)
        model = tf.keras.Model(inputs, outputs)

        # Compile the model with the custom loss function and metric
        model.compile(
            optimizer=optim,
            loss='mse', # MSE_weighted() if using errors
            metrics=[r_factor_metric]

        )
        
        history = model.fit(
        x=features,
        y=labels,  # replace with combined_labels if using errors
        batch_size = features.shape[0], # Use a smaller batch size features.shape[0]
        epochs=n_epochs,
        verbose='auto',
        shuffle=True, # not sure whether this matters
        # callbacks=[cb]
        sample_weight=labels_err  # Use sample weights if you have errors
        )

        histories.append(history)
        all_losses.append(history.history['loss'])
        # Check final loss
        final_loss = history.history['loss'][-1]
        print(model.layers[-1].get_weights()[0].shape)
        curren_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
        print(f"Final loss: {final_loss:.3e}")
        '''
        print(f"Best parameters for iteration {i+1}:")
        for j, par in enumerate(curren_model_pars):
            print(f"Parameter {j+1}: {par.numpy():.4f}")
        '''

        if final_loss < min_loss:
            # Update best model parameters
            best_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
            min_loss = final_loss
            rf = r_factor_metric(labels, fun_tf(features, best_model_pars))
            print(f"Iteration {i+1} - New best loss: {min_loss:.3e} (R-factor: {rf:.3e})")

    if min_loss < best_rf_overall:
        best_rf_overall = min_loss
        best_pars_overall = best_model_pars
        best_loss_overall = all_losses
    print(f"time elapsed: {time() - time_start:.2f} seconds")
    print(f"With {n_epochs*n_iter /(time() - time_start)} iterations per second")
    # Plotting the loss values
    plt.figure(figsize=(10, 6))

    # Plot the loss values for each iteration
    for i, loss_values in enumerate(all_losses):
        plt.plot(loss_values, label=f'Iteration {i+1}')

    plt.title(f'Loss vs Epochs with Learning Rate {learning_rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    # plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# labels shape: (217, 1)
# labels_err shape: (217, 1)
# Learning rate: 0.0008
# max_mode_amps shape: (445,)
# Shape of atom_shift_list: 445
# hello world
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/2000
# Shape of atom_shift_list: 445
# hello world
# Shape of sf_combined: (217,), Shape of x_combined: (217, 3)
# Shape of atom_shift_list: 445
# hello world
# Shape of sf_combined: (217,), Shape of x_combined: (217, 3)
# 1/1 [==============================] - 99s 99s/step - loss: 0.1029 - r_factor_metric: 6.2174
# Epoch 2/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1007 - r_factor_metric: 6.1394
# Epoch 3/2000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0985 - r_factor_metric: 6.0613
# Epoch 4/2000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0965 - r_factor_metric: 5.9844
# Epoch 5/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0945 - r_factor_metric: 5.9114
# Epoch 6/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0925 - r_factor_metric: 5.8401
# Epoch 7/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0907 - r_factor_metric: 5.7714
# Epoch 8/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0890 - r_factor_metric: 5.7130
# Epoch 9/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0874 - r_factor_metric: 5.6553
# Epoch 10/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0858 - r_factor_metric: 5.5965
# Epoch 11/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0841 - r_factor_metric: 5.5325
# Epoch 12/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0825 - r_factor_metric: 5.4614
# Epoch 13/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0810 - r_factor_metric: 5.3972
# Epoch 14/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0796 - r_factor_metric: 5.3443
# Epoch 15/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0782 - r_factor_metric: 5.2858
# Epoch 16/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0767 - r_factor_metric: 5.2191
# Epoch 17/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0754 - r_factor_metric: 5.1639
# Epoch 18/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0742 - r_factor_metric: 5.1052
# Epoch 19/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0731 - r_factor_metric: 5.0564
# Epoch 20/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0721 - r_factor_metric: 5.0173
# Epoch 21/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0711 - r_factor_metric: 4.9793
# Epoch 22/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0701 - r_factor_metric: 4.9362
# Epoch 23/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0692 - r_factor_metric: 4.8911
# Epoch 24/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0682 - r_factor_metric: 4.8473
# Epoch 25/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0672 - r_factor_metric: 4.7997
# Epoch 26/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0663 - r_factor_metric: 4.7518
# Epoch 27/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0653 - r_factor_metric: 4.7055
# Epoch 28/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0643 - r_factor_metric: 4.6519
# Epoch 29/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0634 - r_factor_metric: 4.5979
# Epoch 30/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0624 - r_factor_metric: 4.5469
# Epoch 31/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0615 - r_factor_metric: 4.5020
# Epoch 32/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0606 - r_factor_metric: 4.4561
# Epoch 33/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0597 - r_factor_metric: 4.4151
# Epoch 34/2000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0588 - r_factor_metric: 4.3690
# Epoch 35/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0578 - r_factor_metric: 4.3181
# Epoch 36/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0569 - r_factor_metric: 4.2665
# Epoch 37/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0559 - r_factor_metric: 4.2130
# Epoch 38/2000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0550 - r_factor_metric: 4.1623
# Epoch 39/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0540 - r_factor_metric: 4.1083
# Epoch 40/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0530 - r_factor_metric: 4.0446
# Epoch 41/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0521 - r_factor_metric: 3.9848
# Epoch 42/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0511 - r_factor_metric: 3.9386
# Epoch 43/2000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0502 - r_factor_metric: 3.8938
# Epoch 44/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0493 - r_factor_metric: 3.8408
# Epoch 45/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0484 - r_factor_metric: 3.7837
# Epoch 46/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0475 - r_factor_metric: 3.7330
# Epoch 47/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0468 - r_factor_metric: 3.6890
# Epoch 48/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0462 - r_factor_metric: 3.6457
# Epoch 49/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0456 - r_factor_metric: 3.6069
# Epoch 50/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0451 - r_factor_metric: 3.5670
# Epoch 51/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0446 - r_factor_metric: 3.5397
# Epoch 52/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0441 - r_factor_metric: 3.5113
# Epoch 53/2000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0436 - r_factor_metric: 3.4821
# Epoch 54/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0430 - r_factor_metric: 3.4473
# Epoch 55/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0425 - r_factor_metric: 3.4185
# Epoch 56/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0419 - r_factor_metric: 3.3913
# Epoch 57/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0414 - r_factor_metric: 3.3585
# Epoch 58/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0409 - r_factor_metric: 3.3230
# Epoch 59/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0403 - r_factor_metric: 3.2945
# Epoch 60/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0399 - r_factor_metric: 3.2657
# Epoch 61/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0394 - r_factor_metric: 3.2236
# Epoch 62/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0389 - r_factor_metric: 3.1912
# Epoch 63/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0386 - r_factor_metric: 3.1735
# Epoch 64/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0382 - r_factor_metric: 3.1484
# Epoch 65/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0378 - r_factor_metric: 3.1151
# Epoch 66/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0373 - r_factor_metric: 3.0814
# Epoch 67/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0370 - r_factor_metric: 3.0589
# Epoch 68/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0366 - r_factor_metric: 3.0485
# Epoch 69/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0363 - r_factor_metric: 3.0321
# Epoch 70/2000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0359 - r_factor_metric: 3.0091
# Epoch 71/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0356 - r_factor_metric: 2.9809
# Epoch 72/2000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0353 - r_factor_metric: 2.9507
# Epoch 73/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0349 - r_factor_metric: 2.9240
# Epoch 74/2000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0346 - r_factor_metric: 2.8992
# Epoch 75/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0343 - r_factor_metric: 2.8764
# Epoch 76/2000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0339 - r_factor_metric: 2.8609
# Epoch 77/2000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0336 - r_factor_metric: 2.8498
# Epoch 78/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0333 - r_factor_metric: 2.8298
# Epoch 79/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0330 - r_factor_metric: 2.8029
# Epoch 80/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0327 - r_factor_metric: 2.7744
# Epoch 81/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0324 - r_factor_metric: 2.7491
# Epoch 82/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0320 - r_factor_metric: 2.7257
# Epoch 83/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0317 - r_factor_metric: 2.7043
# Epoch 84/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0315 - r_factor_metric: 2.6852
# Epoch 85/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0312 - r_factor_metric: 2.6643
# Epoch 86/2000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0309 - r_factor_metric: 2.6407
# Epoch 87/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0306 - r_factor_metric: 2.6173
# Epoch 88/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0303 - r_factor_metric: 2.5949
# Epoch 89/2000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0301 - r_factor_metric: 2.5737
# Epoch 90/2000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0298 - r_factor_metric: 2.5529
# Epoch 91/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0296 - r_factor_metric: 2.5358
# Epoch 92/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0293 - r_factor_metric: 2.5151
# Epoch 93/2000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0290 - r_factor_metric: 2.4949
# Epoch 94/2000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0288 - r_factor_metric: 2.4727
# Epoch 95/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0285 - r_factor_metric: 2.4490
# Epoch 96/2000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0282 - r_factor_metric: 2.4261
# Epoch 97/2000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0280 - r_factor_metric: 2.4096
# Epoch 98/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0277 - r_factor_metric: 2.3914
# Epoch 99/2000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0275 - r_factor_metric: 2.3672
# Epoch 100/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0272 - r_factor_metric: 2.3431
# Epoch 101/2000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0270 - r_factor_metric: 2.3262
# Epoch 102/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0267 - r_factor_metric: 2.3100
# Epoch 103/2000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0265 - r_factor_metric: 2.2915
# Epoch 104/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0262 - r_factor_metric: 2.2716
# Epoch 105/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0260 - r_factor_metric: 2.2512
# Epoch 106/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0257 - r_factor_metric: 2.2321
# Epoch 107/2000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0255 - r_factor_metric: 2.2173
# Epoch 108/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0252 - r_factor_metric: 2.2035
# Epoch 109/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0250 - r_factor_metric: 2.1867
# Epoch 110/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0247 - r_factor_metric: 2.1656
# Epoch 111/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0245 - r_factor_metric: 2.1420
# Epoch 112/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0243 - r_factor_metric: 2.1238
# Epoch 113/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0241 - r_factor_metric: 2.1118
# Epoch 114/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0239 - r_factor_metric: 2.1002
# Epoch 115/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0237 - r_factor_metric: 2.0886
# Epoch 116/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0235 - r_factor_metric: 2.0773
# Epoch 117/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0234 - r_factor_metric: 2.0638
# Epoch 118/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0232 - r_factor_metric: 2.0504
# Epoch 119/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0231 - r_factor_metric: 2.0358
# Epoch 120/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0229 - r_factor_metric: 2.0216
# Epoch 121/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0228 - r_factor_metric: 2.0085
# Epoch 122/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0226 - r_factor_metric: 1.9959
# Epoch 123/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0225 - r_factor_metric: 1.9843
# Epoch 124/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0223 - r_factor_metric: 1.9734
# Epoch 125/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0221 - r_factor_metric: 1.9623
# Epoch 126/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0220 - r_factor_metric: 1.9511
# Epoch 127/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0218 - r_factor_metric: 1.9394
# Epoch 128/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0217 - r_factor_metric: 1.9255
# Epoch 129/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0215 - r_factor_metric: 1.9110
# Epoch 130/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0213 - r_factor_metric: 1.9017
# Epoch 131/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0212 - r_factor_metric: 1.8959
# Epoch 132/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0210 - r_factor_metric: 1.8907
# Epoch 133/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0209 - r_factor_metric: 1.8843
# Epoch 134/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0207 - r_factor_metric: 1.8781
# Epoch 135/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0206 - r_factor_metric: 1.8711
# Epoch 136/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0204 - r_factor_metric: 1.8624
# Epoch 137/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0203 - r_factor_metric: 1.8530
# Epoch 138/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0201 - r_factor_metric: 1.8429
# Epoch 139/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0199 - r_factor_metric: 1.8322
# Epoch 140/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0198 - r_factor_metric: 1.8216
# Epoch 141/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0196 - r_factor_metric: 1.8110
# Epoch 142/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0195 - r_factor_metric: 1.7997
# Epoch 143/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0193 - r_factor_metric: 1.7882
# Epoch 144/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0192 - r_factor_metric: 1.7769
# Epoch 145/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0190 - r_factor_metric: 1.7650
# Epoch 146/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0188 - r_factor_metric: 1.7540
# Epoch 147/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0187 - r_factor_metric: 1.7453
# Epoch 148/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0186 - r_factor_metric: 1.7390
# Epoch 149/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0185 - r_factor_metric: 1.7320
# Epoch 150/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0183 - r_factor_metric: 1.7243
# Epoch 151/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0182 - r_factor_metric: 1.7145
# Epoch 152/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0181 - r_factor_metric: 1.7025
# Epoch 153/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0179 - r_factor_metric: 1.6959
# Epoch 154/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0178 - r_factor_metric: 1.6925
# Epoch 155/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0177 - r_factor_metric: 1.6866
# Epoch 156/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0175 - r_factor_metric: 1.6761
# Epoch 157/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0174 - r_factor_metric: 1.6656
# Epoch 158/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - r_factor_metric: 1.6547
# Epoch 159/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0171 - r_factor_metric: 1.6436
# Epoch 160/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0170 - r_factor_metric: 1.6360
# Epoch 161/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0168 - r_factor_metric: 1.6273
# Epoch 162/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0167 - r_factor_metric: 1.6178
# Epoch 163/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0165 - r_factor_metric: 1.6080
# Epoch 164/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0164 - r_factor_metric: 1.6045
# Epoch 165/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0163 - r_factor_metric: 1.6004
# Epoch 166/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0162 - r_factor_metric: 1.5923
# Epoch 167/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0161 - r_factor_metric: 1.5815
# Epoch 168/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0160 - r_factor_metric: 1.5702
# Epoch 169/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0159 - r_factor_metric: 1.5606
# Epoch 170/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0157 - r_factor_metric: 1.5533
# Epoch 171/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0156 - r_factor_metric: 1.5467
# Epoch 172/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0155 - r_factor_metric: 1.5390
# Epoch 173/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0154 - r_factor_metric: 1.5293
# Epoch 174/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0153 - r_factor_metric: 1.5192
# Epoch 175/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0151 - r_factor_metric: 1.5105
# Epoch 176/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0150 - r_factor_metric: 1.5010
# Epoch 177/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0149 - r_factor_metric: 1.4899
# Epoch 178/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0147 - r_factor_metric: 1.4770
# Epoch 179/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0146 - r_factor_metric: 1.4641
# Epoch 180/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0144 - r_factor_metric: 1.4495
# Epoch 181/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0144 - r_factor_metric: 1.4421
# Epoch 182/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0143 - r_factor_metric: 1.4312
# Epoch 183/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0142 - r_factor_metric: 1.4203
# Epoch 184/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0141 - r_factor_metric: 1.4138
# Epoch 185/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0140 - r_factor_metric: 1.4055
# Epoch 186/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0139 - r_factor_metric: 1.3922
# Epoch 187/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0138 - r_factor_metric: 1.3766
# Epoch 188/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0137 - r_factor_metric: 1.3673
# Epoch 189/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0137 - r_factor_metric: 1.3590
# Epoch 190/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0136 - r_factor_metric: 1.3535
# Epoch 191/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0135 - r_factor_metric: 1.3465
# Epoch 192/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0135 - r_factor_metric: 1.3388
# Epoch 193/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0134 - r_factor_metric: 1.3302
# Epoch 194/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0133 - r_factor_metric: 1.3224
# Epoch 195/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0132 - r_factor_metric: 1.3135
# Epoch 196/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0132 - r_factor_metric: 1.3071
# Epoch 197/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0131 - r_factor_metric: 1.3028
# Epoch 198/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0130 - r_factor_metric: 1.3000
# Epoch 199/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0130 - r_factor_metric: 1.2922
# Epoch 200/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0129 - r_factor_metric: 1.2817
# Epoch 201/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0128 - r_factor_metric: 1.2722
# Epoch 202/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0128 - r_factor_metric: 1.2644
# Epoch 203/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0127 - r_factor_metric: 1.2584
# Epoch 204/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0126 - r_factor_metric: 1.2522
# Epoch 205/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0126 - r_factor_metric: 1.2459
# Epoch 206/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0125 - r_factor_metric: 1.2396
# Epoch 207/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0125 - r_factor_metric: 1.2323
# Epoch 208/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0124 - r_factor_metric: 1.2258
# Epoch 209/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0124 - r_factor_metric: 1.2209
# Epoch 210/2000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0123 - r_factor_metric: 1.2161
# Epoch 211/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0123 - r_factor_metric: 1.2105
# Epoch 212/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0122 - r_factor_metric: 1.2041
# Epoch 213/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0122 - r_factor_metric: 1.1972
# Epoch 214/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0121 - r_factor_metric: 1.1919
# Epoch 215/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0121 - r_factor_metric: 1.1885
# Epoch 216/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0120 - r_factor_metric: 1.1845
# Epoch 217/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0120 - r_factor_metric: 1.1807
# Epoch 218/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0119 - r_factor_metric: 1.1782
# Epoch 219/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0119 - r_factor_metric: 1.1750
# Epoch 220/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0119 - r_factor_metric: 1.1714
# Epoch 221/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0118 - r_factor_metric: 1.1680
# Epoch 222/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0118 - r_factor_metric: 1.1647
# Epoch 223/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0117 - r_factor_metric: 1.1622
# Epoch 224/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0117 - r_factor_metric: 1.1591
# Epoch 225/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0116 - r_factor_metric: 1.1557
# Epoch 226/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0116 - r_factor_metric: 1.1525
# Epoch 227/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0115 - r_factor_metric: 1.1486
# Epoch 228/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0115 - r_factor_metric: 1.1450
# Epoch 229/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0114 - r_factor_metric: 1.1419
# Epoch 230/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0114 - r_factor_metric: 1.1384
# Epoch 231/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0113 - r_factor_metric: 1.1350
# Epoch 232/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0113 - r_factor_metric: 1.1318
# Epoch 233/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0112 - r_factor_metric: 1.1290
# Epoch 234/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0112 - r_factor_metric: 1.1269
# Epoch 235/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0111 - r_factor_metric: 1.1250
# Epoch 236/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0111 - r_factor_metric: 1.1231
# Epoch 237/2000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0110 - r_factor_metric: 1.1212
# Epoch 238/2000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0109 - r_factor_metric: 1.1186
# Epoch 239/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0109 - r_factor_metric: 1.1159
# Epoch 240/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0108 - r_factor_metric: 1.1130
# Epoch 241/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0107 - r_factor_metric: 1.1099
# Epoch 242/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0107 - r_factor_metric: 1.1073
# Epoch 243/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0106 - r_factor_metric: 1.1049
# Epoch 244/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0105 - r_factor_metric: 1.1039
# Epoch 245/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0105 - r_factor_metric: 1.1008
# Epoch 246/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0105 - r_factor_metric: 1.0962
# Epoch 247/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0104 - r_factor_metric: 1.0935
# Epoch 248/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0104 - r_factor_metric: 1.0920
# Epoch 249/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0103 - r_factor_metric: 1.0897
# Epoch 250/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0103 - r_factor_metric: 1.0860
# Epoch 251/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0102 - r_factor_metric: 1.0773
# Epoch 252/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0101 - r_factor_metric: 1.0701
# Epoch 253/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0101 - r_factor_metric: 1.0665
# Epoch 254/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0100 - r_factor_metric: 1.0645
# Epoch 255/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0100 - r_factor_metric: 1.0618
# Epoch 256/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0099 - r_factor_metric: 1.0615
# Epoch 257/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0099 - r_factor_metric: 1.0569
# Epoch 258/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0099 - r_factor_metric: 1.0507
# Epoch 259/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0098 - r_factor_metric: 1.0433
# Epoch 260/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0098 - r_factor_metric: 1.0385
# Epoch 261/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0097 - r_factor_metric: 1.0357
# Epoch 262/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0097 - r_factor_metric: 1.0300
# Epoch 263/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0096 - r_factor_metric: 1.0284
# Epoch 264/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0096 - r_factor_metric: 1.0294
# Epoch 265/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0095 - r_factor_metric: 1.0283
# Epoch 266/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0095 - r_factor_metric: 1.0265
# Epoch 267/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0094 - r_factor_metric: 1.0236
# Epoch 268/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0094 - r_factor_metric: 1.0191
# Epoch 269/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0093 - r_factor_metric: 1.0165
# Epoch 270/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0093 - r_factor_metric: 1.0139
# Epoch 271/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0092 - r_factor_metric: 1.0112
# Epoch 272/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0092 - r_factor_metric: 1.0096
# Epoch 273/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0091 - r_factor_metric: 1.0072
# Epoch 274/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0091 - r_factor_metric: 1.0016
# Epoch 275/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0090 - r_factor_metric: 0.9973
# Epoch 276/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0089 - r_factor_metric: 0.9918
# Epoch 277/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0089 - r_factor_metric: 0.9888
# Epoch 278/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0088 - r_factor_metric: 0.9843
# Epoch 279/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0088 - r_factor_metric: 0.9812
# Epoch 280/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0087 - r_factor_metric: 0.9773
# Epoch 281/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0086 - r_factor_metric: 0.9755
# Epoch 282/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0086 - r_factor_metric: 0.9730
# Epoch 283/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0085 - r_factor_metric: 0.9711
# Epoch 284/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0084 - r_factor_metric: 0.9694
# Epoch 285/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0084 - r_factor_metric: 0.9692
# Epoch 286/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0083 - r_factor_metric: 0.9669
# Epoch 287/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0082 - r_factor_metric: 0.9636
# Epoch 288/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0081 - r_factor_metric: 0.9605
# Epoch 289/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0080 - r_factor_metric: 0.9580
# Epoch 290/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0079 - r_factor_metric: 0.9544
# Epoch 291/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0078 - r_factor_metric: 0.9501
# Epoch 292/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0077 - r_factor_metric: 0.9463
# Epoch 293/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0076 - r_factor_metric: 0.9429
# Epoch 294/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0075 - r_factor_metric: 0.9375
# Epoch 295/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0074 - r_factor_metric: 0.9323
# Epoch 296/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0073 - r_factor_metric: 0.9268
# Epoch 297/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0071 - r_factor_metric: 0.9202
# Epoch 298/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0070 - r_factor_metric: 0.9072
# Epoch 299/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0070 - r_factor_metric: 0.9005
# Epoch 300/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0070 - r_factor_metric: 0.9048
# Epoch 301/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0069 - r_factor_metric: 0.9010
# Epoch 302/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0068 - r_factor_metric: 0.8981
# Epoch 303/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0068 - r_factor_metric: 0.8961
# Epoch 304/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0067 - r_factor_metric: 0.8893
# Epoch 305/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0067 - r_factor_metric: 0.8856
# Epoch 306/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0066 - r_factor_metric: 0.8726
# Epoch 307/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0065 - r_factor_metric: 0.8652
# Epoch 308/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0065 - r_factor_metric: 0.8627
# Epoch 309/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0065 - r_factor_metric: 0.8641
# Epoch 310/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0064 - r_factor_metric: 0.8559
# Epoch 311/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0064 - r_factor_metric: 0.8472
# Epoch 312/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0063 - r_factor_metric: 0.8441
# Epoch 313/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0063 - r_factor_metric: 0.8315
# Epoch 314/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0063 - r_factor_metric: 0.8198
# Epoch 315/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0062 - r_factor_metric: 0.8045
# Epoch 316/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0062 - r_factor_metric: 0.8026
# Epoch 317/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0062 - r_factor_metric: 0.8010
# Epoch 318/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0062 - r_factor_metric: 0.7986
# Epoch 319/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0062 - r_factor_metric: 0.7963
# Epoch 320/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0061 - r_factor_metric: 0.7915
# Epoch 321/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0061 - r_factor_metric: 0.7886
# Epoch 322/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0061 - r_factor_metric: 0.7840
# Epoch 323/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0061 - r_factor_metric: 0.7790
# Epoch 324/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0061 - r_factor_metric: 0.7760
# Epoch 325/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0061 - r_factor_metric: 0.7753
# Epoch 326/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0060 - r_factor_metric: 0.7728
# Epoch 327/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0060 - r_factor_metric: 0.7683
# Epoch 328/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0060 - r_factor_metric: 0.7646
# Epoch 329/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0060 - r_factor_metric: 0.7578
# Epoch 330/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0060 - r_factor_metric: 0.7550
# Epoch 331/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0060 - r_factor_metric: 0.7517
# Epoch 332/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0060 - r_factor_metric: 0.7506
# Epoch 333/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0060 - r_factor_metric: 0.7529
# Epoch 334/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0060 - r_factor_metric: 0.7527
# Epoch 335/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0059 - r_factor_metric: 0.7517
# Epoch 336/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0059 - r_factor_metric: 0.7507
# Epoch 337/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0059 - r_factor_metric: 0.7507
# Epoch 338/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0059 - r_factor_metric: 0.7486
# Epoch 339/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0059 - r_factor_metric: 0.7473
# Epoch 340/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0059 - r_factor_metric: 0.7440
# Epoch 341/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0059 - r_factor_metric: 0.7433
# Epoch 342/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0059 - r_factor_metric: 0.7401
# Epoch 343/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0059 - r_factor_metric: 0.7361
# Epoch 344/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0059 - r_factor_metric: 0.7326
# Epoch 345/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0059 - r_factor_metric: 0.7308
# Epoch 346/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0059 - r_factor_metric: 0.7311
# Epoch 347/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0059 - r_factor_metric: 0.7285
# Epoch 348/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0058 - r_factor_metric: 0.7290
# Epoch 349/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0058 - r_factor_metric: 0.7257
# Epoch 350/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0058 - r_factor_metric: 0.7242
# Epoch 351/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0058 - r_factor_metric: 0.7235
# Epoch 352/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0058 - r_factor_metric: 0.7220
# Epoch 353/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0058 - r_factor_metric: 0.7225
# Epoch 354/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0058 - r_factor_metric: 0.7195
# Epoch 355/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0058 - r_factor_metric: 0.7193
# Epoch 356/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0058 - r_factor_metric: 0.7187
# Epoch 357/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0058 - r_factor_metric: 0.7156
# Epoch 358/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0058 - r_factor_metric: 0.7180
# Epoch 359/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0058 - r_factor_metric: 0.7144
# Epoch 360/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0058 - r_factor_metric: 0.7149
# Epoch 361/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0058 - r_factor_metric: 0.7115
# Epoch 362/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0058 - r_factor_metric: 0.7105
# Epoch 363/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0057 - r_factor_metric: 0.7095
# Epoch 364/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0057 - r_factor_metric: 0.7077
# Epoch 365/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0057 - r_factor_metric: 0.7089
# Epoch 366/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0057 - r_factor_metric: 0.7059
# Epoch 367/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0057 - r_factor_metric: 0.7067
# Epoch 368/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0057 - r_factor_metric: 0.7033
# Epoch 369/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0057 - r_factor_metric: 0.7035
# Epoch 370/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0057 - r_factor_metric: 0.7021
# Epoch 371/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0057 - r_factor_metric: 0.7010
# Epoch 372/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0057 - r_factor_metric: 0.7013
# Epoch 373/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0057 - r_factor_metric: 0.6996
# Epoch 374/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0057 - r_factor_metric: 0.6991
# Epoch 375/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0057 - r_factor_metric: 0.6988
# Epoch 376/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0057 - r_factor_metric: 0.6977
# Epoch 377/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0057 - r_factor_metric: 0.6977
# Epoch 378/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0057 - r_factor_metric: 0.6960
# Epoch 379/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0057 - r_factor_metric: 0.6968
# Epoch 380/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0057 - r_factor_metric: 0.6939
# Epoch 381/2000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0056 - r_factor_metric: 0.6952
# Epoch 382/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0056 - r_factor_metric: 0.6926
# Epoch 383/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0056 - r_factor_metric: 0.6935
# Epoch 384/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0056 - r_factor_metric: 0.6912
# Epoch 385/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0056 - r_factor_metric: 0.6923
# Epoch 386/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0056 - r_factor_metric: 0.6899
# Epoch 387/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0056 - r_factor_metric: 0.6905
# Epoch 388/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0056 - r_factor_metric: 0.6891
# Epoch 389/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0056 - r_factor_metric: 0.6888
# Epoch 390/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0056 - r_factor_metric: 0.6877
# Epoch 391/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0056 - r_factor_metric: 0.6878
# Epoch 392/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0056 - r_factor_metric: 0.6866
# Epoch 393/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0056 - r_factor_metric: 0.6864
# Epoch 394/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0056 - r_factor_metric: 0.6856
# Epoch 395/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0056 - r_factor_metric: 0.6855
# Epoch 396/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0056 - r_factor_metric: 0.6843
# Epoch 397/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0056 - r_factor_metric: 0.6846
# Epoch 398/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0056 - r_factor_metric: 0.6832
# Epoch 399/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0056 - r_factor_metric: 0.6834
# Epoch 400/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0055 - r_factor_metric: 0.6818
# Epoch 401/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0055 - r_factor_metric: 0.6827
# Epoch 402/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0055 - r_factor_metric: 0.6809
# Epoch 403/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0055 - r_factor_metric: 0.6822
# Epoch 404/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0055 - r_factor_metric: 0.6802
# Epoch 405/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0055 - r_factor_metric: 0.6806
# Epoch 406/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0055 - r_factor_metric: 0.6786
# Epoch 407/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0055 - r_factor_metric: 0.6786
# Epoch 408/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0055 - r_factor_metric: 0.6779
# Epoch 409/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0055 - r_factor_metric: 0.6770
# Epoch 410/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0055 - r_factor_metric: 0.6776
# Epoch 411/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0055 - r_factor_metric: 0.6758
# Epoch 412/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0055 - r_factor_metric: 0.6769
# Epoch 413/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0055 - r_factor_metric: 0.6751
# Epoch 414/2000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0055 - r_factor_metric: 0.6755
# Epoch 415/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0055 - r_factor_metric: 0.6735
# Epoch 416/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0055 - r_factor_metric: 0.6736
# Epoch 417/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0055 - r_factor_metric: 0.6724
# Epoch 418/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0055 - r_factor_metric: 0.6720
# Epoch 419/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0055 - r_factor_metric: 0.6717
# Epoch 420/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0055 - r_factor_metric: 0.6703
# Epoch 421/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0054 - r_factor_metric: 0.6707
# Epoch 422/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0054 - r_factor_metric: 0.6687
# Epoch 423/2000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0054 - r_factor_metric: 0.6695
# Epoch 424/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0054 - r_factor_metric: 0.6676
# Epoch 425/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0054 - r_factor_metric: 0.6683
# Epoch 426/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0054 - r_factor_metric: 0.6663
# Epoch 427/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0054 - r_factor_metric: 0.6667
# Epoch 428/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0054 - r_factor_metric: 0.6647
# Epoch 429/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0054 - r_factor_metric: 0.6650
# Epoch 430/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0054 - r_factor_metric: 0.6634
# Epoch 431/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0054 - r_factor_metric: 0.6635
# Epoch 432/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0054 - r_factor_metric: 0.6624
# Epoch 433/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0054 - r_factor_metric: 0.6622
# Epoch 434/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0054 - r_factor_metric: 0.6614
# Epoch 435/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0054 - r_factor_metric: 0.6608
# Epoch 436/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0054 - r_factor_metric: 0.6600
# Epoch 437/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0054 - r_factor_metric: 0.6596
# Epoch 438/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0054 - r_factor_metric: 0.6586
# Epoch 439/2000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0054 - r_factor_metric: 0.6585
# Epoch 440/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0054 - r_factor_metric: 0.6574
# Epoch 441/2000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0054 - r_factor_metric: 0.6578
# Epoch 442/2000
# ...
# Epoch 1862/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 8.0088e-04 - r_factor_metric: 0.3099
# Epoch 1863/2000
# 1/1 [==============================] - 0s 106ms/step - loss: 7.7534e-04 - r_factor_metric: 0.3003
# Epoch 1864/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.6497e-04 - r_factor_metric: 0.2973
# Epoch 1865/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.6687e-04 - r_factor_metric: 0.2973
# Epoch 1866/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.8377e-04 - r_factor_metric: 0.3026
# Epoch 1867/2000
# 1/1 [==============================] - 0s 97ms/step - loss: 8.0964e-04 - r_factor_metric: 0.3190
# Epoch 1868/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 8.0987e-04 - r_factor_metric: 0.3132
# Epoch 1869/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.9374e-04 - r_factor_metric: 0.3106
# Epoch 1870/2000
# 1/1 [==============================] - 0s 80ms/step - loss: 7.6887e-04 - r_factor_metric: 0.2957
# Epoch 1871/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 7.5775e-04 - r_factor_metric: 0.2929
# Epoch 1872/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 7.5702e-04 - r_factor_metric: 0.2939
# Epoch 1873/2000
# 1/1 [==============================] - 0s 94ms/step - loss: 7.6544e-04 - r_factor_metric: 0.2965
# Epoch 1874/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 7.8343e-04 - r_factor_metric: 0.3085
# Epoch 1875/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 7.8463e-04 - r_factor_metric: 0.3017
# Epoch 1876/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.9666e-04 - r_factor_metric: 0.3125
# Epoch 1877/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 7.9227e-04 - r_factor_metric: 0.3056
# Epoch 1878/2000
# 1/1 [==============================] - 0s 160ms/step - loss: 7.7276e-04 - r_factor_metric: 0.3005
# Epoch 1879/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 7.6391e-04 - r_factor_metric: 0.2934
# Epoch 1880/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.6418e-04 - r_factor_metric: 0.2963
# Epoch 1881/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 7.7934e-04 - r_factor_metric: 0.3046
# Epoch 1882/2000
# 1/1 [==============================] - 0s 58ms/step - loss: 7.8492e-04 - r_factor_metric: 0.3023
# Epoch 1883/2000
# 1/1 [==============================] - 0s 80ms/step - loss: 8.0604e-04 - r_factor_metric: 0.3116
# Epoch 1884/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.7570e-04 - r_factor_metric: 0.3007
# Epoch 1885/2000
# 1/1 [==============================] - 0s 57ms/step - loss: 7.6127e-04 - r_factor_metric: 0.2965
# Epoch 1886/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.7081e-04 - r_factor_metric: 0.3004
# Epoch 1887/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.9338e-04 - r_factor_metric: 0.3108
# Epoch 1888/2000
# 1/1 [==============================] - 0s 75ms/step - loss: 8.2897e-04 - r_factor_metric: 0.3201
# Epoch 1889/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.9753e-04 - r_factor_metric: 0.3092
# Epoch 1890/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.6845e-04 - r_factor_metric: 0.3010
# Epoch 1891/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.5400e-04 - r_factor_metric: 0.2930
# Epoch 1892/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.6416e-04 - r_factor_metric: 0.2931
# Epoch 1893/2000
# 1/1 [==============================] - 0s 84ms/step - loss: 7.8658e-04 - r_factor_metric: 0.3090
# Epoch 1894/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.9072e-04 - r_factor_metric: 0.3082
# Epoch 1895/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 7.9406e-04 - r_factor_metric: 0.3088
# Epoch 1896/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 7.7224e-04 - r_factor_metric: 0.3040
# Epoch 1897/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.9018e-04 - r_factor_metric: 0.3061
# Epoch 1898/2000
# 1/1 [==============================] - 0s 104ms/step - loss: 8.1382e-04 - r_factor_metric: 0.3208
# Epoch 1899/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 7.9399e-04 - r_factor_metric: 0.3078
# Epoch 1900/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.6742e-04 - r_factor_metric: 0.3008
# Epoch 1901/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.5596e-04 - r_factor_metric: 0.2915
# Epoch 1902/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.6195e-04 - r_factor_metric: 0.2956
# Epoch 1903/2000
# 1/1 [==============================] - 0s 200ms/step - loss: 7.7983e-04 - r_factor_metric: 0.3031
# Epoch 1904/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 7.7264e-04 - r_factor_metric: 0.3001
# Epoch 1905/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 7.7376e-04 - r_factor_metric: 0.3033
# Epoch 1906/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.5622e-04 - r_factor_metric: 0.2926
# Epoch 1907/2000
# 1/1 [==============================] - 0s 87ms/step - loss: 7.5302e-04 - r_factor_metric: 0.2938
# Epoch 1908/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 7.6445e-04 - r_factor_metric: 0.2980
# Epoch 1909/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 7.7031e-04 - r_factor_metric: 0.2993
# Epoch 1910/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 7.8278e-04 - r_factor_metric: 0.3065
# Epoch 1911/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.8035e-04 - r_factor_metric: 0.3044
# Epoch 1912/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 7.8313e-04 - r_factor_metric: 0.3055
# Epoch 1913/2000
# 1/1 [==============================] - 0s 95ms/step - loss: 7.6807e-04 - r_factor_metric: 0.2980
# Epoch 1914/2000
# 1/1 [==============================] - 0s 81ms/step - loss: 7.6201e-04 - r_factor_metric: 0.2932
# Epoch 1915/2000
# 1/1 [==============================] - 0s 101ms/step - loss: 7.5778e-04 - r_factor_metric: 0.2975
# Epoch 1916/2000
# 1/1 [==============================] - 0s 76ms/step - loss: 7.5658e-04 - r_factor_metric: 0.2927
# Epoch 1917/2000
# 1/1 [==============================] - 0s 85ms/step - loss: 7.6192e-04 - r_factor_metric: 0.2976
# Epoch 1918/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 7.5679e-04 - r_factor_metric: 0.2929
# Epoch 1919/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.5652e-04 - r_factor_metric: 0.2979
# Epoch 1920/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.5306e-04 - r_factor_metric: 0.2896
# Epoch 1921/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 7.5112e-04 - r_factor_metric: 0.2921
# Epoch 1922/2000
# 1/1 [==============================] - 0s 104ms/step - loss: 7.5315e-04 - r_factor_metric: 0.2898
# Epoch 1923/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 7.5606e-04 - r_factor_metric: 0.2935
# Epoch 1924/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.6455e-04 - r_factor_metric: 0.2940
# Epoch 1925/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.6999e-04 - r_factor_metric: 0.3001
# Epoch 1926/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 7.7637e-04 - r_factor_metric: 0.3015
# Epoch 1927/2000
# 1/1 [==============================] - 0s 59ms/step - loss: 7.7019e-04 - r_factor_metric: 0.2999
# Epoch 1928/2000
# 1/1 [==============================] - 0s 79ms/step - loss: 7.7126e-04 - r_factor_metric: 0.3011
# Epoch 1929/2000
# 1/1 [==============================] - 0s 77ms/step - loss: 7.6450e-04 - r_factor_metric: 0.2974
# Epoch 1930/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 7.6948e-04 - r_factor_metric: 0.3019
# Epoch 1931/2000
# 1/1 [==============================] - 0s 101ms/step - loss: 7.6052e-04 - r_factor_metric: 0.2950
# Epoch 1932/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 7.5687e-04 - r_factor_metric: 0.2948
# Epoch 1933/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 7.4486e-04 - r_factor_metric: 0.2877
# Epoch 1934/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 7.4238e-04 - r_factor_metric: 0.2864
# Epoch 1935/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 7.4748e-04 - r_factor_metric: 0.2912
# Epoch 1936/2000
# 1/1 [==============================] - 0s 84ms/step - loss: 7.5930e-04 - r_factor_metric: 0.2952
# Epoch 1937/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 7.9277e-04 - r_factor_metric: 0.3047
# Epoch 1938/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.8660e-04 - r_factor_metric: 0.3056
# Epoch 1939/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.8870e-04 - r_factor_metric: 0.3102
# Epoch 1940/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.6962e-04 - r_factor_metric: 0.2996
# Epoch 1941/2000
# 1/1 [==============================] - 0s 109ms/step - loss: 7.7382e-04 - r_factor_metric: 0.3004
# Epoch 1942/2000
# 1/1 [==============================] - 0s 77ms/step - loss: 7.8677e-04 - r_factor_metric: 0.3112
# Epoch 1943/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 7.9243e-04 - r_factor_metric: 0.3074
# Epoch 1944/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.8842e-04 - r_factor_metric: 0.3108
# Epoch 1945/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 7.6098e-04 - r_factor_metric: 0.2950
# Epoch 1946/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.4729e-04 - r_factor_metric: 0.2900
# Epoch 1947/2000
# 1/1 [==============================] - 0s 115ms/step - loss: 7.4090e-04 - r_factor_metric: 0.2851
# Epoch 1948/2000
# 1/1 [==============================] - 0s 82ms/step - loss: 7.4401e-04 - r_factor_metric: 0.2881
# Epoch 1949/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 7.5364e-04 - r_factor_metric: 0.2960
# Epoch 1950/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.6005e-04 - r_factor_metric: 0.2943
# Epoch 1951/2000
# 1/1 [==============================] - 0s 96ms/step - loss: 7.7758e-04 - r_factor_metric: 0.3067
# Epoch 1952/2000
# 1/1 [==============================] - 0s 74ms/step - loss: 7.7308e-04 - r_factor_metric: 0.2989
# Epoch 1953/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.7102e-04 - r_factor_metric: 0.3044
# Epoch 1954/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.7114e-04 - r_factor_metric: 0.2978
# Epoch 1955/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 7.6311e-04 - r_factor_metric: 0.2969
# Epoch 1956/2000
# 1/1 [==============================] - 0s 101ms/step - loss: 7.6617e-04 - r_factor_metric: 0.3001
# Epoch 1957/2000
# 1/1 [==============================] - 0s 73ms/step - loss: 7.6925e-04 - r_factor_metric: 0.2993
# Epoch 1958/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.8896e-04 - r_factor_metric: 0.3055
# Epoch 1959/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.7298e-04 - r_factor_metric: 0.3009
# Epoch 1960/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.5936e-04 - r_factor_metric: 0.2981
# Epoch 1961/2000
# 1/1 [==============================] - 0s 82ms/step - loss: 7.4220e-04 - r_factor_metric: 0.2892
# Epoch 1962/2000
# 1/1 [==============================] - 0s 75ms/step - loss: 7.4921e-04 - r_factor_metric: 0.2901
# Epoch 1963/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 7.7321e-04 - r_factor_metric: 0.3034
# Epoch 1964/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.7255e-04 - r_factor_metric: 0.2999
# Epoch 1965/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 7.7347e-04 - r_factor_metric: 0.3035
# Epoch 1966/2000
# 1/1 [==============================] - 0s 68ms/step - loss: 7.4867e-04 - r_factor_metric: 0.2908
# Epoch 1967/2000
# 1/1 [==============================] - 0s 105ms/step - loss: 7.5338e-04 - r_factor_metric: 0.2952
# Epoch 1968/2000
# 1/1 [==============================] - 0s 63ms/step - loss: 7.8672e-04 - r_factor_metric: 0.3101
# Epoch 1969/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 8.1138e-04 - r_factor_metric: 0.3172
# Epoch 1970/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 8.1873e-04 - r_factor_metric: 0.3187
# Epoch 1971/2000
# 1/1 [==============================] - 0s 99ms/step - loss: 7.6848e-04 - r_factor_metric: 0.3000
# Epoch 1972/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.5342e-04 - r_factor_metric: 0.2947
# Epoch 1973/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.8078e-04 - r_factor_metric: 0.3093
# Epoch 1974/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.8551e-04 - r_factor_metric: 0.3029
# Epoch 1975/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 7.7784e-04 - r_factor_metric: 0.3016
# Epoch 1976/2000
# 1/1 [==============================] - 0s 101ms/step - loss: 7.5891e-04 - r_factor_metric: 0.3012
# Epoch 1977/2000
# 1/1 [==============================] - 0s 121ms/step - loss: 7.8926e-04 - r_factor_metric: 0.3050
# Epoch 1978/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 8.2892e-04 - r_factor_metric: 0.3295
# Epoch 1979/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.9971e-04 - r_factor_metric: 0.3096
# Epoch 1980/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.5305e-04 - r_factor_metric: 0.2949
# Epoch 1981/2000
# 1/1 [==============================] - 0s 80ms/step - loss: 7.4780e-04 - r_factor_metric: 0.2947
# Epoch 1982/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 7.6658e-04 - r_factor_metric: 0.2973
# Epoch 1983/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.9598e-04 - r_factor_metric: 0.3185
# Epoch 1984/2000
# 1/1 [==============================] - 0s 79ms/step - loss: 8.0437e-04 - r_factor_metric: 0.3144
# Epoch 1985/2000
# 1/1 [==============================] - 0s 112ms/step - loss: 8.0462e-04 - r_factor_metric: 0.3142
# Epoch 1986/2000
# 1/1 [==============================] - 0s 78ms/step - loss: 7.8283e-04 - r_factor_metric: 0.3113
# Epoch 1987/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.6689e-04 - r_factor_metric: 0.2996
# Epoch 1988/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 7.6722e-04 - r_factor_metric: 0.3022
# Epoch 1989/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 7.5356e-04 - r_factor_metric: 0.3001
# Epoch 1990/2000
# 1/1 [==============================] - 0s 69ms/step - loss: 7.6455e-04 - r_factor_metric: 0.3005
# Epoch 1991/2000
# 1/1 [==============================] - 0s 77ms/step - loss: 7.9760e-04 - r_factor_metric: 0.3096
# Epoch 1992/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.9364e-04 - r_factor_metric: 0.3141
# Epoch 1993/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.9129e-04 - r_factor_metric: 0.3108
# Epoch 1994/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.6628e-04 - r_factor_metric: 0.2996
# Epoch 1995/2000
# 1/1 [==============================] - 0s 96ms/step - loss: 7.4597e-04 - r_factor_metric: 0.2910
# Epoch 1996/2000
# 1/1 [==============================] - 0s 72ms/step - loss: 7.6567e-04 - r_factor_metric: 0.3033
# Epoch 1997/2000
# 1/1 [==============================] - 0s 61ms/step - loss: 7.7233e-04 - r_factor_metric: 0.3011
# Epoch 1998/2000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.8588e-04 - r_factor_metric: 0.3024
# Epoch 1999/2000
# 1/1 [==============================] - 0s 98ms/step - loss: 7.7400e-04 - r_factor_metric: 0.3064
# Epoch 2000/2000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.4776e-04 - r_factor_metric: 0.2904
# (445,)
# Final loss: 7.478e-04
# Shape of atom_shift_list: 445
# hello world
# Shape of sf_combined: (217,), Shape of x_combined: (217, 3)
# Iteration 2 - New best loss: 7.478e-04 (R-factor: 2.736e+02)
# time elapsed: 514.22 seconds
# With 7.778830754535691 iterations per second

# %%
all_losses = best_loss_overall
best_model_pars = best_pars_overall
min_loss = best_rf_overall

print(f"min loss: {min_loss}")

# Plotting the loss values
plt.figure(figsize=(10, 6))

# Plot the loss values for each iteration
for i, loss_values in enumerate(all_losses):
    plt.plot(loss_values, label=f'Iteration {i+1}')

plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.grid(True)
plt.show()
# Out:
# min loss: 0.0007477639010176063

# %%
mode_names = pd.read_csv('raw_data/displacivemode_names.txt' , delim_whitespace=True, header=None)
mode_names = mode_names.values.tolist()
mode_names = pd.DataFrame(mode_names)


# Print the best model parameters
print("Best model parameters:") 
for i, par in enumerate(best_model_pars):
    print(f"mode a{i+1} {mode_names.iloc[i, 1]} : {par.numpy():.8f}")
    
# Print the model summary
print("Number of iterations:", n_iter)
print("Number of features:", n_features)
model.summary()
#modes = get_mode_amplitudes_p63(*best_model_pars)
#print("Modes:")
##for key, val in modes.items():
    #print(f"{key}: {val*1000:.4f}")
# Out:
# Best model parameters:
# mode a1 [1/9,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.16091962
# mode a2 [1/9,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.01579582
# mode a3 [0,1/9,0]DT1(a,0)[Pr1:h:dsp]B2u(a) : 0.04335641
# mode a4 [0,2/9,0]DT1(a,0)[Pr1:h:dsp]B2u(a) : -0.02398709
# mode a5 [0,1/3,0]DT1(a,0)[Pr1:h:dsp]B2u(a) : -0.01594178
# mode a6 [0,4/9,0]DT1(a,0)[Pr1:h:dsp]B2u(a) : -0.01013087
# mode a7 [1/9,0,0]SM1(a,0)[Pr1:h:dsp]B3u(a) : 0.00312995
# mode a8 [2/9,0,0]SM1(a,0)[Pr1:h:dsp]B3u(a) : 0.07378192
# mode a9 [1/3,0,0]SM1(a,0)[Pr1:h:dsp]B3u(a) : -0.06849656
# mode a10 [4/9,0,0]SM1(a,0)[Pr1:h:dsp]B3u(a) : 0.07935812
# mode a11 [1/9,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.18730795
# mode a12 [1/9,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : -0.00135919
# mode a13 [1/9,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.23010753
# mode a14 [1/9,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.04125164
# mode a15 [1/9,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.15074527
# mode a16 [1/9,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.01604017
# mode a17 [2/9,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.18672116
# mode a18 [2/9,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : -0.02615413
# mode a19 [2/9,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.28714231
# mode a20 [2/9,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.07136586
# mode a21 [2/9,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.09219263
# mode a22 [2/9,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : -0.04277242
# mode a23 [2/9,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.02389624
# mode a24 [2/9,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.01465234
# mode a25 [1/3,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.16163255
# mode a26 [1/3,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.02809235
# mode a27 [1/3,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.15314285
# mode a28 [1/3,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : -0.01653109
# mode a29 [1/3,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.06323884
# mode a30 [1/3,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.01080881
# mode a31 [1/3,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.02714191
# mode a32 [1/3,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : -0.01004505
# mode a33 [4/9,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : -0.10143158
# mode a34 [4/9,1/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.01661982
# mode a35 [4/9,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.08147595
# mode a36 [4/9,2/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : -0.04630601
# mode a37 [4/9,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.28518260
# mode a38 [4/9,1/3,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.06711752
# mode a39 [4/9,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B3u(a) : 0.00994559
# mode a40 [4/9,4/9,0]V1(a,0;a,0)[Pr1:h:dsp]B2u(a) : 0.00294487
# mode a41 [1/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.24700859
# mode a42 [1/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.01155543
# mode a43 [1/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.10290063
# mode a44 [0,0,0]GM1+(a)[Ba1:t:dsp]A1(a) : -1.14387143
# mode a45 [0,1/9,0]DT1(a,0)[Ba1:t:dsp]A1(a) : -0.90628737
# mode a46 [0,1/9,0]DT1(a,0)[Ba1:t:dsp]B2(a) : -0.03228328
# mode a47 [0,2/9,0]DT1(a,0)[Ba1:t:dsp]A1(a) : -0.92002040
# mode a48 [0,2/9,0]DT1(a,0)[Ba1:t:dsp]B2(a) : 0.02041622
# mode a49 [0,1/3,0]DT1(a,0)[Ba1:t:dsp]A1(a) : -0.51419383
# mode a50 [0,1/3,0]DT1(a,0)[Ba1:t:dsp]B2(a) : 0.01354731
# mode a51 [0,4/9,0]DT1(a,0)[Ba1:t:dsp]A1(a) : 0.94433069
# mode a52 [0,4/9,0]DT1(a,0)[Ba1:t:dsp]B2(a) : 0.00810048
# mode a53 [1/9,0,0]SM1(a,0)[Ba1:t:dsp]A1(a) : -0.55475122
# mode a54 [1/9,0,0]SM1(a,0)[Ba1:t:dsp]B1(a) : -0.17235370
# mode a55 [2/9,0,0]SM1(a,0)[Ba1:t:dsp]A1(a) : 0.95180380
# mode a56 [2/9,0,0]SM1(a,0)[Ba1:t:dsp]B1(a) : -0.00477910
# mode a57 [1/3,0,0]SM1(a,0)[Ba1:t:dsp]A1(a) : 0.02681302
# mode a58 [1/3,0,0]SM1(a,0)[Ba1:t:dsp]B1(a) : 0.26997578
# mode a59 [4/9,0,0]SM1(a,0)[Ba1:t:dsp]A1(a) : -0.69749856
# mode a60 [4/9,0,0]SM1(a,0)[Ba1:t:dsp]B1(a) : 0.22445275
# mode a61 [1/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.68095243
# mode a62 [1/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.01579629
# mode a63 [1/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.14842385
# mode a64 [1/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.09853441
# mode a65 [1/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.01386939
# mode a66 [1/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : -0.13825475
# mode a67 [1/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.28147933
# mode a68 [1/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.02194907
# mode a69 [1/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.16423239
# mode a70 [2/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.43990842
# mode a71 [2/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.02396469
# mode a72 [2/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.10785483
# mode a73 [2/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.60037172
# mode a74 [2/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.01779700
# mode a75 [2/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.15637459
# mode a76 [2/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.56046969
# mode a77 [2/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : 0.03546093
# mode a78 [2/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : -0.03733244
# mode a79 [2/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.09923089
# mode a80 [2/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.02059233
# mode a81 [2/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.03496679
# mode a82 [1/3,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.71971923
# mode a83 [1/3,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.01428550
# mode a84 [1/3,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.15043032
# mode a85 [1/3,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.32006308
# mode a86 [1/3,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : 0.02824710
# mode a87 [1/3,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.05651049
# mode a88 [1/3,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.31463385
# mode a89 [1/3,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.02881598
# mode a90 [1/3,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : -0.11532106
# mode a91 [1/3,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.35850888
# mode a92 [1/3,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.00733948
# mode a93 [1/3,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.05531632
# mode a94 [4/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.58335203
# mode a95 [4/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : 0.01176489
# mode a96 [4/9,1/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : 0.05309570
# mode a97 [4/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : 0.37575662
# mode a98 [4/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.00576370
# mode a99 [4/9,2/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : -0.02090310
# mode a100 [4/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.40155292
# mode a101 [4/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : 0.05857417
# mode a102 [4/9,1/3,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : -0.14692988
# mode a103 [4/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]A1(a) : -0.50496894
# mode a104 [4/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B2(a) : -0.01244878
# mode a105 [4/9,4/9,0]V1(a,0;a,0)[Ba1:t:dsp]B1(a) : -0.06197634
# mode a106 [1/9,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.07882348
# mode a107 [1/9,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.01101977
# mode a108 [0,1/9,0]DT1(a,0)[Cu1:a:dsp]B2u(a) : -0.01029100
# mode a109 [0,2/9,0]DT1(a,0)[Cu1:a:dsp]B2u(a) : -0.08594736
# mode a110 [0,1/3,0]DT1(a,0)[Cu1:a:dsp]B2u(a) : -0.02339964
# mode a111 [0,4/9,0]DT1(a,0)[Cu1:a:dsp]B2u(a) : -0.05803443
# mode a112 [1/9,0,0]SM1(a,0)[Cu1:a:dsp]B3u(a) : -0.63164246
# mode a113 [2/9,0,0]SM1(a,0)[Cu1:a:dsp]B3u(a) : 0.36793521
# mode a114 [1/3,0,0]SM1(a,0)[Cu1:a:dsp]B3u(a) : -0.23484389
# mode a115 [4/9,0,0]SM1(a,0)[Cu1:a:dsp]B3u(a) : 0.42758077
# mode a116 [1/9,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.20981289
# mode a117 [1/9,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.00704586
# mode a118 [1/9,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.09505713
# mode a119 [1/9,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.02148546
# mode a120 [1/9,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.06017084
# mode a121 [1/9,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.06416100
# mode a122 [2/9,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.34225622
# mode a123 [2/9,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.01135391
# mode a124 [2/9,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.13068430
# mode a125 [2/9,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.01355276
# mode a126 [2/9,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.12051284
# mode a127 [2/9,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.09409793
# mode a128 [2/9,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.14197835
# mode a129 [2/9,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.00259886
# mode a130 [1/3,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.28579298
# mode a131 [1/3,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.07389489
# mode a132 [1/3,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.12550460
# mode a133 [1/3,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.00144817
# mode a134 [1/3,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.16951837
# mode a135 [1/3,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.11590815
# mode a136 [1/3,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.26143607
# mode a137 [1/3,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.03527356
# mode a138 [4/9,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.27965897
# mode a139 [4/9,1/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.07266852
# mode a140 [4/9,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : -0.67606831
# mode a141 [4/9,2/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : 0.00945107
# mode a142 [4/9,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.36306608
# mode a143 [4/9,1/3,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.05462551
# mode a144 [4/9,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B3u(a) : 0.23615299
# mode a145 [4/9,4/9,0]V1(a,0;a,0)[Cu1:a:dsp]B2u(a) : -0.02266907
# mode a146 [1/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.69041920
# mode a147 [1/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.09419328
# mode a148 [1/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.05467375
# mode a149 [0,0,0]GM1+(a)[Cu2:q:dsp]A1(a) : 1.17012322
# mode a150 [0,1/9,0]DT1(a,0)[Cu2:q:dsp]A1(a) : 0.45773327
# mode a151 [0,1/9,0]DT1(a,0)[Cu2:q:dsp]B2(a) : 0.03550025
# mode a152 [0,2/9,0]DT1(a,0)[Cu2:q:dsp]A1(a) : 0.98584569
# mode a153 [0,2/9,0]DT1(a,0)[Cu2:q:dsp]B2(a) : 0.04192029
# mode a154 [0,1/3,0]DT1(a,0)[Cu2:q:dsp]A1(a) : -1.03226662
# mode a155 [0,1/3,0]DT1(a,0)[Cu2:q:dsp]B2(a) : -0.04056777
# mode a156 [0,4/9,0]DT1(a,0)[Cu2:q:dsp]A1(a) : 0.21883066
# mode a157 [0,4/9,0]DT1(a,0)[Cu2:q:dsp]B2(a) : 0.04770569
# mode a158 [1/9,0,0]SM1(a,0)[Cu2:q:dsp]A1(a) : 0.15123947
# mode a159 [1/9,0,0]SM1(a,0)[Cu2:q:dsp]B1(a) : -0.56492400
# mode a160 [2/9,0,0]SM1(a,0)[Cu2:q:dsp]A1(a) : -0.74068874
# mode a161 [2/9,0,0]SM1(a,0)[Cu2:q:dsp]B1(a) : 0.35073495
# mode a162 [1/3,0,0]SM1(a,0)[Cu2:q:dsp]A1(a) : 0.11946842
# mode a163 [1/3,0,0]SM1(a,0)[Cu2:q:dsp]B1(a) : 0.04809163
# mode a164 [4/9,0,0]SM1(a,0)[Cu2:q:dsp]A1(a) : -0.55224580
# mode a165 [4/9,0,0]SM1(a,0)[Cu2:q:dsp]B1(a) : -0.07659877
# mode a166 [1/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.51063919
# mode a167 [1/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : 0.02008402
# mode a168 [1/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.12733868
# mode a169 [1/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.71020305
# mode a170 [1/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.03612283
# mode a171 [1/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.03895712
# mode a172 [1/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.34551990
# mode a173 [1/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : 0.02779376
# mode a174 [1/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.07809196
# mode a175 [2/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.27096030
# mode a176 [2/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.04599665
# mode a177 [2/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.17199349
# mode a178 [2/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.22500746
# mode a179 [2/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.03249922
# mode a180 [2/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.00759724
# mode a181 [2/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.56842679
# mode a182 [2/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.02941235
# mode a183 [2/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.04593716
# mode a184 [2/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.39567411
# mode a185 [2/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.00696829
# mode a186 [2/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.07546601
# mode a187 [1/3,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.46788245
# mode a188 [1/3,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : 0.04019570
# mode a189 [1/3,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.03793479
# mode a190 [1/3,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.56032187
# mode a191 [1/3,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.01288193
# mode a192 [1/3,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.08740731
# mode a193 [1/3,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.61148471
# mode a194 [1/3,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : 0.06071167
# mode a195 [1/3,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.10404286
# mode a196 [1/3,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.41423318
# mode a197 [1/3,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.00082301
# mode a198 [1/3,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.21832022
# mode a199 [4/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.03388125
# mode a200 [4/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : 0.01914672
# mode a201 [4/9,1/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.11936547
# mode a202 [4/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : -0.42602283
# mode a203 [4/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.04208963
# mode a204 [4/9,2/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : 0.26304820
# mode a205 [4/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.16061258
# mode a206 [4/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : 0.01511009
# mode a207 [4/9,1/3,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.30183783
# mode a208 [4/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]A1(a) : 0.31892821
# mode a209 [4/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B2(a) : -0.01939269
# mode a210 [4/9,4/9,0]V1(a,0;a,0)[Cu2:q:dsp]B1(a) : -0.27770725
# mode a211 [1/9,1/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.44440028
# mode a212 [1/9,1/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.25935751
# mode a213 [0,1/9,0]DT1(a,0)[O1:e:dsp]B2u(a) : -0.11088407
# mode a214 [0,2/9,0]DT1(a,0)[O1:e:dsp]B2u(a) : -0.09242778
# mode a215 [0,1/3,0]DT1(a,0)[O1:e:dsp]B2u(a) : 0.18951513
# mode a216 [0,4/9,0]DT1(a,0)[O1:e:dsp]B2u(a) : -0.08426139
# mode a217 [1/9,0,0]SM1(a,0)[O1:e:dsp]B3u(a) : 0.74535394
# mode a218 [2/9,0,0]SM1(a,0)[O1:e:dsp]B3u(a) : 0.34414130
# mode a219 [1/3,0,0]SM1(a,0)[O1:e:dsp]B3u(a) : -0.68164080
# mode a220 [4/9,0,0]SM1(a,0)[O1:e:dsp]B3u(a) : 0.03621882
# mode a221 [1/9,2/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.07511351
# mode a222 [1/9,2/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.11401336
# mode a223 [1/9,1/3,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.32680511
# mode a224 [1/9,1/3,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.04817648
# mode a225 [1/9,4/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.12152160
# mode a226 [1/9,4/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.04384794
# mode a227 [2/9,1/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.37825426
# mode a228 [2/9,1/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.07893316
# mode a229 [2/9,2/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.34574059
# mode a230 [2/9,2/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.02813660
# mode a231 [2/9,1/3,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.46779245
# mode a232 [2/9,1/3,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.01921270
# mode a233 [2/9,4/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.38069868
# mode a234 [2/9,4/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.08830361
# mode a235 [1/3,1/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.41872224
# mode a236 [1/3,1/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.01371635
# mode a237 [1/3,2/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.02985661
# mode a238 [1/3,2/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.04230684
# mode a239 [1/3,1/3,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.45995730
# mode a240 [1/3,1/3,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.05232488
# mode a241 [1/3,4/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.26035890
# mode a242 [1/3,4/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.10767858
# mode a243 [4/9,1/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.55351460
# mode a244 [4/9,1/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.22337545
# mode a245 [4/9,2/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : 0.82788944
# mode a246 [4/9,2/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.01807639
# mode a247 [4/9,1/3,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.08338594
# mode a248 [4/9,1/3,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : -0.38785017
# mode a249 [4/9,4/9,0]V1(a,0;a,0)[O1:e:dsp]B3u(a) : -0.42008793
# mode a250 [4/9,4/9,0]V1(a,0;a,0)[O1:e:dsp]B2u(a) : 0.11558143
# mode a251 [1/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.39978823
# mode a252 [1/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.30830386
# mode a253 [1/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.07076913
# mode a254 [0,0,0]GM1+(a)[O2:s:dsp]A1(a) : -0.98265070
# mode a255 [0,1/9,0]DT1(a,0)[O2:s:dsp]A1(a) : -0.15666367
# mode a256 [0,1/9,0]DT1(a,0)[O2:s:dsp]B2(a) : -0.07029524
# mode a257 [0,2/9,0]DT1(a,0)[O2:s:dsp]A1(a) : -0.95481902
# mode a258 [0,2/9,0]DT1(a,0)[O2:s:dsp]B2(a) : -0.04686440
# mode a259 [0,1/3,0]DT1(a,0)[O2:s:dsp]A1(a) : -0.87977546
# mode a260 [0,1/3,0]DT1(a,0)[O2:s:dsp]B2(a) : -0.00151072
# mode a261 [0,4/9,0]DT1(a,0)[O2:s:dsp]A1(a) : -0.70286268
# mode a262 [0,4/9,0]DT1(a,0)[O2:s:dsp]B2(a) : 0.01965629
# mode a263 [1/9,0,0]SM1(a,0)[O2:s:dsp]A1(a) : -0.46802995
# mode a264 [1/9,0,0]SM1(a,0)[O2:s:dsp]B1(a) : -0.02707411
# mode a265 [2/9,0,0]SM1(a,0)[O2:s:dsp]A1(a) : 0.10714348
# mode a266 [2/9,0,0]SM1(a,0)[O2:s:dsp]B1(a) : -0.11126220
# mode a267 [1/3,0,0]SM1(a,0)[O2:s:dsp]A1(a) : -0.67017806
# mode a268 [1/3,0,0]SM1(a,0)[O2:s:dsp]B1(a) : -0.18943176
# mode a269 [4/9,0,0]SM1(a,0)[O2:s:dsp]A1(a) : -0.77437609
# mode a270 [4/9,0,0]SM1(a,0)[O2:s:dsp]B1(a) : -0.46431160
# mode a271 [1/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : -0.35714087
# mode a272 [1/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.34398255
# mode a273 [1/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.06747052
# mode a274 [1/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : -0.66420722
# mode a275 [1/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.11454844
# mode a276 [1/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.20480867
# mode a277 [1/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.62141979
# mode a278 [1/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.23804538
# mode a279 [1/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.47488707
# mode a280 [2/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.33213422
# mode a281 [2/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.08927672
# mode a282 [2/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.16730525
# mode a283 [2/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.73205495
# mode a284 [2/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.23163910
# mode a285 [2/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 1.02709162
# mode a286 [2/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.31858778
# mode a287 [2/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.21531570
# mode a288 [2/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.18374488
# mode a289 [2/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : -0.56471002
# mode a290 [2/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.05468414
# mode a291 [2/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.05588058
# mode a292 [1/3,1/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.70534825
# mode a293 [1/3,1/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.01753222
# mode a294 [1/3,1/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.39125738
# mode a295 [1/3,2/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : -0.16544032
# mode a296 [1/3,2/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.00154565
# mode a297 [1/3,2/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.67380822
# mode a298 [1/3,1/3,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : -0.34562013
# mode a299 [1/3,1/3,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.04326425
# mode a300 [1/3,1/3,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.34917653
# mode a301 [1/3,4/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.59954578
# mode a302 [1/3,4/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.03507459
# mode a303 [1/3,4/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.05674085
# mode a304 [4/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : -0.59614062
# mode a305 [4/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : 0.09898854
# mode a306 [4/9,1/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.09859762
# mode a307 [4/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.46437970
# mode a308 [4/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.12739208
# mode a309 [4/9,2/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : -0.59953833
# mode a310 [4/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.05870954
# mode a311 [4/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.02332717
# mode a312 [4/9,1/3,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.24987115
# mode a313 [4/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]A1(a) : 0.16885801
# mode a314 [4/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]B2(a) : -0.05623223
# mode a315 [4/9,4/9,0]V1(a,0;a,0)[O2:s:dsp]B1(a) : 0.36091319
# mode a316 [1/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.20812704
# mode a317 [1/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.06733442
# mode a318 [1/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.15698686
# mode a319 [0,0,0]GM1+(a)[O3:r:dsp]A1(a) : 0.43106151
# mode a320 [0,1/9,0]DT1(a,0)[O3:r:dsp]A1(a) : 0.13735323
# mode a321 [0,1/9,0]DT1(a,0)[O3:r:dsp]B2(a) : 0.02250739
# mode a322 [0,2/9,0]DT1(a,0)[O3:r:dsp]A1(a) : 0.75292331
# mode a323 [0,2/9,0]DT1(a,0)[O3:r:dsp]B2(a) : 0.01895404
# mode a324 [0,1/3,0]DT1(a,0)[O3:r:dsp]A1(a) : 0.90941823
# mode a325 [0,1/3,0]DT1(a,0)[O3:r:dsp]B2(a) : -0.10260855
# mode a326 [0,4/9,0]DT1(a,0)[O3:r:dsp]A1(a) : 0.54901481
# mode a327 [0,4/9,0]DT1(a,0)[O3:r:dsp]B2(a) : 0.08411603
# mode a328 [1/9,0,0]SM1(a,0)[O3:r:dsp]A1(a) : -0.31266400
# mode a329 [1/9,0,0]SM1(a,0)[O3:r:dsp]B1(a) : 0.20139016
# mode a330 [2/9,0,0]SM1(a,0)[O3:r:dsp]A1(a) : 0.46785152
# mode a331 [2/9,0,0]SM1(a,0)[O3:r:dsp]B1(a) : 0.70927340
# mode a332 [1/3,0,0]SM1(a,0)[O3:r:dsp]A1(a) : 0.53696311
# mode a333 [1/3,0,0]SM1(a,0)[O3:r:dsp]B1(a) : -1.04156756
# mode a334 [4/9,0,0]SM1(a,0)[O3:r:dsp]A1(a) : -0.21000692
# mode a335 [4/9,0,0]SM1(a,0)[O3:r:dsp]B1(a) : 0.34019816
# mode a336 [1/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.64765286
# mode a337 [1/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.04749772
# mode a338 [1/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.51332867
# mode a339 [1/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.56807154
# mode a340 [1/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.11532582
# mode a341 [1/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.23034912
# mode a342 [1/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.17894998
# mode a343 [1/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.02065982
# mode a344 [1/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.30714273
# mode a345 [2/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.11637494
# mode a346 [2/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.03666079
# mode a347 [2/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.30687118
# mode a348 [2/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.28138617
# mode a349 [2/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.03088554
# mode a350 [2/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.75985020
# mode a351 [2/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.01801855
# mode a352 [2/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.26011178
# mode a353 [2/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.38789392
# mode a354 [2/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.59457785
# mode a355 [2/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.04996945
# mode a356 [2/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.45526055
# mode a357 [1/3,1/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.10363919
# mode a358 [1/3,1/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.00412502
# mode a359 [1/3,1/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.41647327
# mode a360 [1/3,2/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.18676290
# mode a361 [1/3,2/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.10717449
# mode a362 [1/3,2/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.08087232
# mode a363 [1/3,1/3,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.10220142
# mode a364 [1/3,1/3,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.02537677
# mode a365 [1/3,1/3,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.48705766
# mode a366 [1/3,4/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.38438284
# mode a367 [1/3,4/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.02882992
# mode a368 [1/3,4/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.00252051
# mode a369 [4/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.35943925
# mode a370 [4/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.02278691
# mode a371 [4/9,1/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.78622389
# mode a372 [4/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : -0.23039173
# mode a373 [4/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : 0.11463749
# mode a374 [4/9,2/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.71912330
# mode a375 [4/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.64237219
# mode a376 [4/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.14153191
# mode a377 [4/9,1/3,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : 0.41934639
# mode a378 [4/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]A1(a) : 0.41777667
# mode a379 [4/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]B2(a) : -0.07585678
# mode a380 [4/9,4/9,0]V1(a,0;a,0)[O3:r:dsp]B1(a) : -0.41422099
# mode a381 [1/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.67646366
# mode a382 [1/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.18921165
# mode a383 [1/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.06867351
# mode a384 [0,0,0]GM1+(a)[O4:q:dsp]A1(a) : 0.14728424
# mode a385 [0,1/9,0]DT1(a,0)[O4:q:dsp]A1(a) : 0.97900832
# mode a386 [0,1/9,0]DT1(a,0)[O4:q:dsp]B2(a) : -0.22261959
# mode a387 [0,2/9,0]DT1(a,0)[O4:q:dsp]A1(a) : -0.98702681
# mode a388 [0,2/9,0]DT1(a,0)[O4:q:dsp]B2(a) : 0.13149634
# mode a389 [0,1/3,0]DT1(a,0)[O4:q:dsp]A1(a) : 0.02838123
# mode a390 [0,1/3,0]DT1(a,0)[O4:q:dsp]B2(a) : 0.28430691
# mode a391 [0,4/9,0]DT1(a,0)[O4:q:dsp]A1(a) : -0.83573556
# mode a392 [0,4/9,0]DT1(a,0)[O4:q:dsp]B2(a) : -0.03404999
# mode a393 [1/9,0,0]SM1(a,0)[O4:q:dsp]A1(a) : -0.44414273
# mode a394 [1/9,0,0]SM1(a,0)[O4:q:dsp]B1(a) : -0.63695604
# mode a395 [2/9,0,0]SM1(a,0)[O4:q:dsp]A1(a) : -0.46898389
# mode a396 [2/9,0,0]SM1(a,0)[O4:q:dsp]B1(a) : 0.27044943
# mode a397 [1/3,0,0]SM1(a,0)[O4:q:dsp]A1(a) : -0.40373147
# mode a398 [1/3,0,0]SM1(a,0)[O4:q:dsp]B1(a) : -0.83124280
# mode a399 [4/9,0,0]SM1(a,0)[O4:q:dsp]A1(a) : -0.36042151
# mode a400 [4/9,0,0]SM1(a,0)[O4:q:dsp]B1(a) : 0.76580489
# mode a401 [1/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.43143243
# mode a402 [1/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.17770948
# mode a403 [1/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.47874695
# mode a404 [1/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.71454060
# mode a405 [1/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.06738217
# mode a406 [1/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.03372227
# mode a407 [1/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.02134769
# mode a408 [1/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.04043295
# mode a409 [1/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.21555074
# mode a410 [2/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.46003491
# mode a411 [2/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.22034617
# mode a412 [2/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.23562181
# mode a413 [2/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.37489316
# mode a414 [2/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.06622007
# mode a415 [2/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.17478077
# mode a416 [2/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.67817277
# mode a417 [2/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.04398362
# mode a418 [2/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.34890863
# mode a419 [2/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.41748393
# mode a420 [2/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.03902145
# mode a421 [2/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.59853560
# mode a422 [1/3,1/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.26630026
# mode a423 [1/3,1/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.09948126
# mode a424 [1/3,1/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.68067622
# mode a425 [1/3,2/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.36128166
# mode a426 [1/3,2/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.03293349
# mode a427 [1/3,2/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.31417951
# mode a428 [1/3,1/3,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.01087586
# mode a429 [1/3,1/3,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.01422450
# mode a430 [1/3,1/3,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.38962004
# mode a431 [1/3,4/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.13599387
# mode a432 [1/3,4/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.01066347
# mode a433 [1/3,4/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.39642888
# mode a434 [4/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.40215632
# mode a435 [4/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.00030041
# mode a436 [4/9,1/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.62608486
# mode a437 [4/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.41847226
# mode a438 [4/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.00691837
# mode a439 [4/9,2/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : -0.12738800
# mode a440 [4/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : 0.30822805
# mode a441 [4/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : 0.00067317
# mode a442 [4/9,1/3,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.05052071
# mode a443 [4/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]A1(a) : -0.37877238
# mode a444 [4/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]B2(a) : -0.04973460
# mode a445 [4/9,4/9,0]V1(a,0;a,0)[O4:q:dsp]B1(a) : 0.43367323
# Number of iterations: 2
# Number of features: 217
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 3)]               0
#
#  fun_as_layer_6 (FunAsLayer)  (None,)                  445
#
# =================================================================
# Total params: 445
# Trainable params: 445
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\User\AppData\Local\Temp\ipykernel_18788\2645836416.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mode_names = pd.read_csv('raw_data/displacivemode_names.txt' , delim_whitespace=True, header=None)

# %%
def plot_plane_sim_vs_exp(ax, df, l, norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.max(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.max(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], exp_data_0['k'], 
               s=np.log10(exp_data_0['intensity_sim'] + 1) * 10000, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="left"))
    ax.scatter(exp_data_0['h'] , exp_data_0['k'] , s=np.log10(exp_data_0['intensity_exp'] + 1) * 10000  , color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="right"))
    #ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               #s=exp_data_0['intensity_exp'] * 300, color='blue', edgecolor="black",
               #label='Exp', marker=MarkerStyle("o", fillstyle="right"))
    
    #grid on
    ax.grid(True, linestyle='--', alpha=0.7)
    #adjust x axis ticks
    ax.set_xticks(np.arange(0, 5, 0.11))
    ax.set_yticks(np.arange(0, 5, 0.11))
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    '''if data_char == 'best':
        ax.set_title(f"l = {l}, best")
    else:
        ax.set_title(f"l = {l} , current")'''
    ax.legend()

# %%
exp_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/raw_data/peaks1.csv')
exp_data['intensity_sim'] = fun_tf(features, best_model_pars).numpy()
# Out:
# Shape of atom_shift_list: 445
# hello world
# Shape of sf_combined: (217,), Shape of x_combined: (217, 3)

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 20), constrained_layout=True)

plot_plane_sim_vs_exp(axs, exp_data, 0, norm_plane=True)
plt.show()

# %%
#save the experiment data with simulated intensities
exp_data.to_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/fitted_data/peaks_with_simulated_intensities.txt', index=False)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/fitted_data/parameters_and_modes.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars):
        f.write(f"{mode_names.iloc[i, 1]} : {par.numpy():.8f} \n")

abs_params = tf.abs(best_model_pars)
best_model_pars_compare = best_model_pars.numpy()
best_model_pars_compare = best_model_pars_compare / np.max(best_model_pars_compare)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/fitted_data/parameters_and_modes_normalised.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars_compare):
        f.write(f"{mode_names.iloc[i, 1]} : {par:.8f} \n")

# %%
best_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/fitted_data/peaks_with_simulated_intensities.txt')

fig, axs = plt.subplots(1, 2, figsize=(24, 12), constrained_layout=True)
plot_plane_sim_vs_exp(axs[0], best_data, 0, norm_plane=True)
plot_plane_sim_vs_exp(axs[1], exp_data, 0, norm_plane=True)

plt.show()
